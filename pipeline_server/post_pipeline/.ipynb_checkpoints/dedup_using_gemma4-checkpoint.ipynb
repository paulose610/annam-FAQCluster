# %%
import requests

def gemma_4_26b_it_completion(prompt, max_tokens=512, temperature=0.0, top_p=0.95, stop=None):
    """
    Wrapper function to call the google/gemma-3-12b-it model, exposed via OpenAI-style API.

    Args:
        prompt (str): The prompt to send to the model.
        max_tokens (int): The maximum number of tokens to generate.
        temperature (float): Sampling temperature.
        top_p (float): Nucleus sampling probability.
        stop (list or str, optional): Stop sequence(s).

    Returns:
        str: The model's generated text completion.
    """
    api_url = "http://100.100.108.44:8013/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    data = {
        "model": "google/gemma-4-26B-A4B-it",
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": max_tokens,
        "temperature": temperature,
        "top_p": top_p,
    }
    if stop is not None:
        data["stop"] = stop

    response = requests.post(api_url, headers=headers, json=data)
    if response.status_code == 200:
        completion = response.json()
        return completion['choices'][0]['message']['content']
    else:
        raise RuntimeError(f"Failed to fetch completion: {response.status_code} - {response.text}")

# %%
import pandas as pd
import re
import json
from tqdm.auto import tqdm

def deduplicate_and_aggregate(df, text_col='Generated_Question', batch_size=100):
    """
    Iterates through categories, finds similar questions using LLM, 
    aggregates 'raw_frequency', and removes duplicates with full logging.
    """
    # Ensure raw_frequency is numeric to allow summing
    df['raw_frequency'] = pd.to_numeric(df['raw_frequency'], errors='coerce').fillna(0)

    phase_data = []
    final_cleaned_data = []
    categories = df['Generated_Category'].unique()

    # Outer progress bar for categories
    category_pbar = tqdm(categories, desc="Processing Categories", position=0)

    for category in category_pbar:
        # Update progress bar postfix to show current category
        category_pbar.set_postfix({"Current": category})
        
        tqdm.write(f"\n{'='*70}")
        tqdm.write(f"🚀 STARTING CATEGORY: {category}")
        tqdm.write(f"{'='*70}")
        
        # Isolate rows for the current category
        cat_df = df[df['Generated_Category'] == category].copy()
        total_initial = len(cat_df)
        tqdm.write(f"[INFO] Total rows to process in '{category}': {total_initial}")
        
        # Loop until no rows are left in this category's pool
        while not cat_df.empty:
            # Pop the first row to act as the reference
            ref_phase = []
            reference_row = cat_df.iloc[0].copy()
            ref_phase.append({                                                                     
                      'representative_question': reference_row['representative_question']
                  })
            ref_id = reference_row['unique_q_id']
            ref_question = reference_row[text_col]
            current_freq = reference_row['raw_frequency']
            
            # The candidates are all OTHER rows in this category
            remaining_df = cat_df.iloc[1:].reset_index(drop=True)
            
            if remaining_df.empty:
                tqdm.write(f"\n[INFO] Only 1 row left in category. Saving Reference [{ref_id}] directly.")
                final_cleaned_data.append(reference_row.to_dict())
                break
                
            tqdm.write(f"\n🔍 Evaluating Reference [{ref_id}]: {ref_question} (Current Freq: {current_freq})")
            tqdm.write(f"   Candidates remaining in pool: {len(remaining_df)}")
            
            # Find matches using the 2-pass LLM approach
            matched_ids, ref_phase = _get_verified_matches(reference_row, remaining_df, text_col, batch_size, ref_phase)
            
            if matched_ids:
                # Isolate the matched rows
                matches_df = remaining_df[remaining_df['unique_q_id'].isin(matched_ids)]

                ## Adding info to ref_phase
                ref_phase = pd.concat([                                                                            
                            ref_phase,
                            matches_df[['representative_question', 'unique_q_id']].rename(columns={                 
                                    'representative_question': 'phase_2',                                      
                                    'unique_q_id': 'phase_2_id'
                            }).reset_index(drop=True)                                                          
                            ], axis=1)

                
                phase_2_ids = set(ref_phase['phase_2_id'].dropna())   
                removed_mask = ~ref_phase['phase_1_id'].isin(phase_2_ids)
                ref_phase['false_positive'] = ref_phase.loc[removed_mask, 'phase_1']                   
                false_positives = ref_phase['false_positive'].dropna()
                ref_phase['false_positive'] = false_positives                                          
                ref_phase.drop(columns=['phase_1_id', 'phase_2_id'], inplace=True)                     
                ref_phase = ref_phase[['representative_question', 'phase_1', 'false_positive','phase_2']]                                                                                
                ref_phase = pd.concat([ref_phase, pd.DataFrame([{}])], ignore_index=True)

                phase_data.append(ref_phase)
                
                # Sum the raw_frequency of the matches
                summed_frequency = matches_df['raw_frequency'].sum()
    
                tqdm.write(f"   ✅ SUCCESS: Found {len(matched_ids)} verified matches.")
                for _, m_row in matches_df.iterrows():
                    tqdm.write(f"      -> Matched [{m_row['unique_q_id']}]: {m_row[text_col]} (Freq: {m_row['raw_frequency']})")
                    
                tqdm.write(f"   📈 Aggregating Frequencies: {current_freq} + {summed_frequency} = {current_freq + summed_frequency}")
                    
                # Add it to the reference row
                reference_row['raw_frequency'] += summed_frequency
                    
                # Remove matched rows from the remaining pool
                cat_df = remaining_df[~remaining_df['unique_q_id'].isin(matched_ids)].reset_index(drop=True)
                tqdm.write(f"   🗑️  Removed {len(matched_ids)} matches from the pool. New pool size: {len(cat_df)}")
                
            else:
                tqdm.write("   ❌ No matches found. Moving to next row.")
                # No matches, so the next pool is just the remaining items
                cat_df = remaining_df
                    
                # Save the updated reference row to our final list
                final_cleaned_data.append(reference_row.to_dict())

            print(phase_data[-1].to_dict())

    tqdm.write(f"\n{'='*70}\n🎉 PROCESSING COMPLETE\n{'='*70}")
    tqdm.write(f"Original Dataset Size: {len(df)}")
    tqdm.write(f"Cleaned Dataset Size: {len(final_cleaned_data)}")
    
    # Return the clean, aggregated DataFrame
    return pd.DataFrame(final_cleaned_data), pd.concat(phase_data, ignore_index=True)


def _get_verified_matches(reference_row, candidate_df, text_col, batch_size, ref_phase):
    """
    Helper function running the 2-pass LLM matching logic with batch-level progress and logging.
    """
    original_id = reference_row['unique_q_id']
    original_question = reference_row[text_col]
    
    all_candidate_ids = []
    
    # Calculate total batches for tqdm
    total_batches = (len(candidate_df) + batch_size - 1) // batch_size

    # --- PASS 1: Batch Initial Search ---
    tqdm.write("   [Pass 1] Scanning for initial candidates...")
    
    # Inner progress bar for batches (leave=False hides it after it finishes)
    for start in tqdm(range(0, len(candidate_df), batch_size), total=total_batches, desc="Pass 1 Batches", leave=False):
        batch = candidate_df.iloc[start:start+batch_size]

        batch_text = "\n".join([
            f"{row['unique_q_id']}: {row[text_col]}"
            for _, row in batch.iterrows()
        ])

        prompt = f"""
You are given one reference question and a list of candidate questions.
Task: Return ONLY the IDs of questions that exact same or rephrased to the reference question.
Rules:
- Output ONLY a JSON list of matching IDs
- No explanation
- If none match, return []

Reference:
{original_id}: {original_question}

Candidates:
{batch_text}

Output:
"""
        # Call your LLM here
        response = gemma_4_26b_it_completion(prompt, max_tokens=2000, temperature=0.0)

        match = re.search(r'\[.*\]', response, re.DOTALL)
        if match:
            try:
                found_in_batch = json.loads(match.group(0))
                if found_in_batch:
                    tqdm.write(f"      -> Batch flagged {len(found_in_batch)} potential IDs: {found_in_batch}")
                all_candidate_ids.extend(found_in_batch)
            except json.JSONDecodeError:
                tqdm.write("      -> [WARNING] JSON decoding failed in Pass 1 for a batch.")

    ref_phase = pd.DataFrame(ref_phase)
    
    # --- PASS 2: Verification ---
    if not all_candidate_ids:
        return [], ref_phase
    
    tqdm.write(f"   [Pass 2] Verifying {len(all_candidate_ids)} potential candidates...")
    candidate_rows = candidate_df[candidate_df['unique_q_id'].isin(all_candidate_ids)]

    #adding info to ref_phase
    ref_phase = pd.concat([                                                                            
                ref_phase,
                candidate_rows[['representative_question', 'unique_q_id']].rename(columns={                 
                                        'representative_question': 'phase_1',                                      
                                        'unique_q_id': 'phase_1_id'
                                }).reset_index(drop=True)                                                          
                                ], axis=1)
    
    verification_batch_text = "\n".join([
        f"{row['unique_q_id']}: {row[text_col]}"
        for _, row in candidate_rows.iterrows()
    ])

    verification_prompt = f"""
Task: Strictly review these candidates. Remove any questions that are NOT the exact same or a direct rephrase.
Rules: Output ONLY a JSON list of matching IDs. No explanation. If none match, return [].

Reference:
{original_id}: {original_question}

Candidates to Verify:
{verification_batch_text}

Output:
"""
    verification_response = gemma_4_26b_it_completion(verification_prompt, max_tokens=2000, temperature=0.0)

    final_matched_ids = []
    final_match = re.search(r'\[.*\]', verification_response, re.DOTALL)
    if final_match:
        try:
            final_matched_ids = json.loads(final_match.group(0))
        except json.JSONDecodeError:
            tqdm.write("      -> [WARNING] JSON decoding failed in Pass 2.")

    # Filter out any hallucinated IDs that weren't actually in the candidates pool
    final_matched_ids = [mid for mid in final_matched_ids if mid in all_candidate_ids]

    return final_matched_ids, ref_phase

# %%
from pathlib import Path
import pandas as pd

crops_folder = Path('../outputs/repair/final')


for csv_file in crops_folder.glob("*.csv"):
    print(f"Processing: {csv_file.name}")

    output_name_phase = f"phase_data_{csv_file.name}"
    output_name_final = f"dedup_{csv_file.name}"
    
    output_path_phase = crops_folder / output_name_phase
    output_path_final = crops_folder / output_name_final
    
    try:
        # Read CSV
        df = pd.read_csv(csv_file, low_memory=False)

        # Risky step
        df, df1 = deduplicate_and_aggregate(df)

    except Exception as e:
        print(f"[ERROR] Failed processing {csv_file.name}: {e}")
        continue  # skip this file and move to next

    # Save intermediate
    df1.to_csv(output_path_phase, index=False)

    # Filter
    df = df[df['answer_label'] != "(unclassified)"]

    # Save final
    df.to_csv(output_path_final, index=False)

    print(f"Saved phase output: {output_name_phase}")
    print(f"Saved final output: {output_name_final}")
# Out:
# Processing: beans_faq.csv
# Processing Categories:   0%|          | 0/10 [00:00<?, ?it/s]
# ======================================================================
# 🚀 STARTING CATEGORY: Pest
# ======================================================================
# [INFO] Total rows to process in 'Pest': 151
#
# 🔍 Evaluating Reference [255_1]: I am facing pest issues in my bean crop. What measures should I take to protect my plants? (Current Freq: 505)
#    Candidates remaining in pool: 150
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 15 potential IDs: ['10_1', '237_2', '158_2', '289_1', '158_1', '124_1', '255_2', '293_2', '255_4', '212_1', '297_5', '10_3', '116_2', '27_1', '104_1']
#       -> Batch flagged 2 potential IDs: ['255_3', '116_1']
#    [Pass 2] Verifying 17 potential candidates...
#    ✅ SUCCESS: Found 12 verified matches.
#       -> Matched [10_1]: What are the common pests that affect beans and how can they be controlled? (Freq: 387)
#       -> Matched [237_2]: What are the common pests that affect beans and how can they be controlled? (Freq: 149)
#       -> Matched [158_2]: What are the common pests that affect beans and how can they be managed? (Freq: 35)
#       -> Matched [289_1]: What are the common pests that affect beans and how can they be controlled? (Freq: 20)
#       -> Matched [158_1]: What are the common pests that affect beans and how can they be managed? (Freq: 18)
#       -> Matched [124_1]: What are the common pests affecting beans and how can they be managed? (Freq: 17)
#       -> Matched [255_4]: What are the common pests that affect beans and how can they be controlled? (Freq: 15)
#       -> Matched [212_1]: What are the common pests that affect beans and how can they be managed? (Freq: 10)
#       -> Matched [293_2]: What are the common pests that affect beans and how can they be controlled? (Freq: 6)
#       -> Matched [255_2]: What are the common pests that affect beans and how can they be controlled? (Freq: 5)
#       -> Matched [116_2]: What are the common pests that affect beans and how can they be controlled? (Freq: 4)
#       -> Matched [297_5]: What are the common pests that affect beans and how can they be controlled? (Freq: 2)
#    📈 Aggregating Frequencies: 505 + 668 = 1173
#    🗑️  Removed 12 matches from the pool. New pool size: 138
# {'representative_question': {0: 'Asked about plant protection', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan, 9: nan, 10: nan, 11: nan, 12: nan, 13: nan, 14: nan, 15: nan, 16: nan, 17: nan}, 'phase_1': {0: 'Asked about plant protection in beans', 1: 'beans pest', 2: 'Asked about pest management in Beans', 3: 'PEST', 4: 'Asked about Pest management in  Beans', 5: 'DOLICHOS PEST', 6: 'ASKED ABOUT THE PLANT PROTECTION', 7: 'Asked about Pest management', 8: 'asking for beans pest', 9: 'Asked about the plant protection in ', 10: 'Asked about plant protection inbeans', 11: 'Asked about plant protection Beans', 12: 'Asked about Plant protection in Pulses', 13: 'Asked about plant protection in     hirekayi', 14: 'pests', 15: 'Asked about plant protection in    ', 16: 'Asked about plant protection in bbeans', 17: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan, 9: nan, 10: 'Asked about plant protection inbeans', 11: 'Asked about plant protection Beans', 12: nan, 13: 'Asked about plant protection in     hirekayi', 14: nan, 15: 'Asked about plant protection in    ', 16: 'Asked about plant protection in bbeans', 17: nan}, 'phase_2': {0: 'Asked about plant protection in beans', 1: 'beans pest', 2: 'Asked about pest management in Beans', 3: 'PEST', 4: 'Asked about Pest management in  Beans', 5: 'DOLICHOS PEST', 6: 'ASKED ABOUT THE PLANT PROTECTION', 7: 'Asked about Pest management', 8: 'asking for beans pest', 9: 'Asked about the plant protection in ', 10: 'Asked about Plant protection in Pulses', 11: 'pests', 12: nan, 13: nan, 14: nan, 15: nan, 16: nan, 17: nan}}
#
# 🔍 Evaluating Reference [10_5]: Asked about plant protection in field bean (Current Freq: 68)
#    Candidates remaining in pool: 137
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 5 potential IDs: ['158_5', '26_2', '27_1', '104_1', '10_3']
#       -> Batch flagged 3 potential IDs: ['289_2', '255_3', '116_1']
#    [Pass 2] Verifying 8 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [26_2]: What are the common pests that affect Fieldbean and how can they be controlled? (Freq: 16)
#       -> Matched [158_5]: What are the common pests that affect field beans and how can they be managed? (Freq: 5)
#       -> Matched [289_2]: What are the common pests that affect field beans and how can they be managed? (Freq: 1)
#    📈 Aggregating Frequencies: 68 + 22 = 90
#    🗑️  Removed 3 matches from the pool. New pool size: 134
# {'representative_question': {0: 'Asked about plant protection in field bean', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan}, 'phase_1': {0: 'Asked about plant protection in  Fieldbean ', 1: 'Asked about  pest management in  Field bean  ', 2: 'Asked about plant protection inbeans', 3: 'Asked about plant protection Beans', 4: 'Asked about plant protection in     hirekayi', 5: 'fieldbean pest', 6: 'Asked about plant protection in    ', 7: 'Asked about plant protection in bbeans', 8: nan}, 'false_positive': {0: nan, 1: nan, 2: 'Asked about plant protection inbeans', 3: 'Asked about plant protection Beans', 4: 'Asked about plant protection in     hirekayi', 5: nan, 6: 'Asked about plant protection in    ', 7: 'Asked about plant protection in bbeans', 8: nan}, 'phase_2': {0: 'Asked about plant protection in  Fieldbean ', 1: 'Asked about  pest management in  Field bean  ', 2: 'fieldbean pest', 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan}}
#
# 🔍 Evaluating Reference [189_1]: Beans flower dropping (Current Freq: 63)
#    Candidates remaining in pool: 133
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['189_3']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [189_3]: Flower dropping in beans (Freq: 3)
#    📈 Aggregating Frequencies: 63 + 3 = 66
#    🗑️  Removed 1 matches from the pool. New pool size: 132
# {'representative_question': {0: 'beans flower dropping', 1: nan}, 'phase_1': {0: 'flower dropping in beans', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'flower dropping in beans', 1: nan}}
#
# 🔍 Evaluating Reference [297_1]: What are the common sucking pests that affect beans and how can they be controlled? (Current Freq: 50)
#    Candidates remaining in pool: 131
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['265_1', '299_1', '294_1', '293_4']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 4 verified matches.
#       -> Matched [265_1]: Asking about management of sucking pests in beans. (Freq: 12)
#       -> Matched [299_1]: What are the common sucking pests that affect beans and how can they be managed? (Freq: 6)
#       -> Matched [294_1]: What are the control measures for sucking pests in beans? (Freq: 4)
#       -> Matched [293_4]: What is the best management strategy for sucking pests in beans? (Freq: 3)
#    📈 Aggregating Frequencies: 50 + 25 = 75
#    🗑️  Removed 4 matches from the pool. New pool size: 127
# {'representative_question': {0: 'sucking pest', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'ASKING ABOUT BEANS SUCKING PEST MANAGEMENT', 1: 'ASKED FOR :BEANS SUCKING PEST', 2: 'SUCKING PEST CONTROL MEASURES', 3: '.asked about sucking pest management in beans \n', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_2': {0: 'ASKING ABOUT BEANS SUCKING PEST MANAGEMENT', 1: 'ASKED FOR :BEANS SUCKING PEST', 2: 'SUCKING PEST CONTROL MEASURES', 3: '.asked about sucking pest management in beans \n', 4: nan}}
#
# 🔍 Evaluating Reference [259_1]: What should I do if I notice bean borers in my crop? (Current Freq: 31)
#    Candidates remaining in pool: 126
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 6 potential IDs: ['261_1', '251_1', '260_2', '318_3', '243_1', '262_1']
#       -> Batch flagged 1 potential IDs: ['251_4']
#    [Pass 2] Verifying 7 potential candidates...
#    ✅ SUCCESS: Found 4 verified matches.
#       -> Matched [261_1]: What is the best way to manage the beans pod borer? (Freq: 9)
#       -> Matched [251_1]: Asking about pod borer management in beans (Freq: 9)
#       -> Matched [262_1]: Asked about pod borer control in field bean (Freq: 6)
#       -> Matched [251_4]: Asking for management of beans borer (Freq: 1)
#    📈 Aggregating Frequencies: 31 + 25 = 56
#    🗑️  Removed 4 matches from the pool. New pool size: 122
# {'representative_question': {0: 'borer', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}, 'phase_1': {0: 'asking for beans pod borer', 1: 'ASKING ABOUT POD BORER MANAGEMENT IN BEANS', 2: 'Asked about  pod borer control in field bean ', 3: 'Beans pod borer and disease', 4: 'bens pod borer', 5: 'bean pod borere', 6: 'ASKING FOR BEANS BORER MANAGEMENT', 7: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: 'Beans pod borer and disease', 4: 'bens pod borer', 5: 'bean pod borere', 6: nan, 7: nan}, 'phase_2': {0: 'asking for beans pod borer', 1: 'ASKING ABOUT POD BORER MANAGEMENT IN BEANS', 2: 'Asked about  pod borer control in field bean ', 3: 'ASKING FOR BEANS BORER MANAGEMENT', 4: nan, 5: nan, 6: nan, 7: nan}}
#
# 🔍 Evaluating Reference [60_1]: What are the common pests that affect cluster beans and how can they be controlled? (Current Freq: 30)
#    Candidates remaining in pool: 121
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['185_2', '158_6']
#       -> Batch flagged 2 potential IDs: ['237_3', '237_4']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [185_2]: What are the common pests that affect clusterbean and how can they be managed? (Freq: 4)
#       -> Matched [158_6]: What are the common pests affecting cluster beans and how can they be managed? (Freq: 3)
#    📈 Aggregating Frequencies: 30 + 7 = 37
#    🗑️  Removed 2 matches from the pool. New pool size: 119
# {'representative_question': {0: 'Asked about plant protection in Cluster bean', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'clusterbean pest', 1: 'Asked about  pest management in cluster bean ', 2: 'cluster beans pest', 3: 'field beans pest', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: 'cluster beans pest', 3: 'field beans pest', 4: nan}, 'phase_2': {0: 'clusterbean pest', 1: 'Asked about  pest management in cluster bean ', 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [286_8]: What is the best way to manage leaf miner in beans? (Current Freq: 28)
#    Candidates remaining in pool: 118
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['325_1', '158_4']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [325_1]: Asking about the management of beans leaf minors. (Freq: 5)
#       -> Matched [158_4]: What is the best approach to manage leaf minor pests in beans? (Freq: 1)
#    📈 Aggregating Frequencies: 28 + 6 = 34
#    🗑️  Removed 2 matches from the pool. New pool size: 116
# {'representative_question': {0: 'leaf miner', 1: nan, 2: nan}, 'phase_1': {0: 'ASKING ABOUT BEANS LEAF MINOR MANAGEMENT', 1: 'Asked about leaf minor Pest management in Beans', 2: nan}, 'false_positive': {0: nan, 1: nan, 2: nan}, 'phase_2': {0: 'ASKING ABOUT BEANS LEAF MINOR MANAGEMENT', 1: 'Asked about leaf minor Pest management in Beans', 2: nan}}
#
# 🔍 Evaluating Reference [260_1]: Pod borer (Current Freq: 27)
#    Candidates remaining in pool: 115
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['260_2', '243_1', '318_3', '238_2']
#       -> Batch flagged 1 potential IDs: ['125_2']
#    [Pass 2] Verifying 5 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [260_2]: Beans pod borer (Freq: 2)
#       -> Matched [318_3]: Bean pod borer (Freq: 1)
#       -> Matched [238_2]: Pod borer of field bean (Freq: 1)
#    📈 Aggregating Frequencies: 27 + 4 = 31
#    🗑️  Removed 3 matches from the pool. New pool size: 112
# {'representative_question': {0: 'pod borer', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'Beans pod borer and disease', 1: 'bens pod borer', 2: 'bean pod borere', 3: 'pod borer of field bean', 4: 'pod borer in dolichos bean', 5: nan}, 'false_positive': {0: 'Beans pod borer and disease', 1: nan, 2: nan, 3: nan, 4: 'pod borer in dolichos bean', 5: nan}, 'phase_2': {0: 'bens pod borer', 1: 'bean pod borere', 2: 'pod borer of field bean', 3: nan, 4: nan, 5: nan}}
#
# 🔍 Evaluating Reference [146_1]: What should I do if I notice leaf-eating caterpillars on my bean plants? (Current Freq: 21)
#    Candidates remaining in pool: 111
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['145_1', '327_1', '146_3', '318_4']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [327_1]: Asking about the management of field bean leaf-eating caterpillars. (Freq: 2)
#       -> Matched [146_3]: Caterpillars are feeding on the leaves of my bean plants. (Freq: 1)
#    📈 Aggregating Frequencies: 21 + 3 = 24
#    🗑️  Removed 2 matches from the pool. New pool size: 109
# {'representative_question': {0: 'leaf eating caterpillar', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'leaf eating caterpiller', 1: 'ASKING ABOUT FIELD BEAN LEAF EATING CATERPILLER MANAGEMENT', 2: 'Caterpillar feed on the leaf', 3: 'bean catterpiller', 4: nan}, 'false_positive': {0: 'leaf eating caterpiller', 1: nan, 2: nan, 3: 'bean catterpiller', 4: nan}, 'phase_2': {0: 'ASKING ABOUT FIELD BEAN LEAF EATING CATERPILLER MANAGEMENT', 1: 'Caterpillar feed on the leaf', 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [32_1]: Asked about Plant protection in cowpea (Current Freq: 19)
#    Candidates remaining in pool: 108
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['79_1', '309_1', '212_6', '32_2']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 4 verified matches.
#       -> Matched [79_1]: What are the common pests that affect cowpea and how can they be controlled? (Freq: 7)
#       -> Matched [309_1]: What are the common pests affecting cowpea and how can they be managed? (Freq: 6)
#       -> Matched [212_6]: What are the common pests that affect Cowpea and how can they be managed? (Freq: 3)
#       -> Matched [32_2]: Cowpea plant protection (Freq: 2)
#    📈 Aggregating Frequencies: 19 + 18 = 37
#    🗑️  Removed 4 matches from the pool. New pool size: 104
# {'representative_question': {0: 'Asked about Plant protection in cowpea', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'Asked about plant protection in cow pea', 1: 'cowpea pest', 2: 'Asked about pest management in Cowpea', 3: 'Cowpea plant protection', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_2': {0: 'Asked about plant protection in cow pea', 1: 'cowpea pest', 2: 'Asked about pest management in Cowpea', 3: 'Cowpea plant protection', 4: nan}}
#
# 🔍 Evaluating Reference [46_1]: What are the common plant protection chemicals used for beans and how should they be applied? (Current Freq: 18)
#    Candidates remaining in pool: 103
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 5 potential IDs: ['27_1', '10_3', '104_1', '255_3', '116_1']
#    [Pass 2] Verifying 5 potential candidates...
#    ✅ SUCCESS: Found 5 verified matches.
#       -> Matched [27_1]: Asked about plant protection in beans (Freq: 5)
#       -> Matched [10_3]: Asked about plant protection for Beans (Freq: 5)
#       -> Matched [104_1]: Asked about plant protection in beans (Freq: 2)
#       -> Matched [255_3]: Asked about plant protection in beans. (Freq: 1)
#       -> Matched [116_1]: Asked about plant protection in beans (Freq: 1)
#    📈 Aggregating Frequencies: 18 + 14 = 32
#    🗑️  Removed 5 matches from the pool. New pool size: 98
# {'representative_question': {0: 'PLANT PROTECTION CHEMICALS', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'Asked about plant protection inbeans', 1: 'Asked about plant protection Beans', 2: 'Asked about plant protection in     hirekayi', 3: 'Asked about plant protection in    ', 4: 'Asked about plant protection in bbeans', 5: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_2': {0: 'Asked about plant protection inbeans', 1: 'Asked about plant protection Beans', 2: 'Asked about plant protection in     hirekayi', 3: 'Asked about plant protection in    ', 4: 'Asked about plant protection in bbeans', 5: nan}}
#
# 🔍 Evaluating Reference [209_1]: Aphids in Field Bean (Current Freq: 16)
#    Candidates remaining in pool: 97
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['208_2', '208_1', '70_2', '293_3']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [208_2]: What should I do if I notice aphids on my bean plants? (Freq: 16)
#       -> Matched [293_3]: How can I control aphids in my bean crop? (Freq: 2)
#    📈 Aggregating Frequencies: 16 + 18 = 34
#    🗑️  Removed 2 matches from the pool. New pool size: 95
# {'representative_question': {0: 'Aphids IN FIELD BEAN', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'aphids', 1: 'APHID IN AVARE', 2: 'Asked about Plant Protection in  dolichos bean control of aphids', 3: 'asking for beans aphid control', 4: nan}, 'false_positive': {0: nan, 1: 'APHID IN AVARE', 2: 'Asked about Plant Protection in  dolichos bean control of aphids', 3: nan, 4: nan}, 'phase_2': {0: 'aphids', 1: 'asking for beans aphid control', 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [285_1]: Leaf eater (Current Freq: 16)
#    Candidates remaining in pool: 94
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 5 potential IDs: ['285_2', '145_1', '146_2', '146_5', '318_4']
#    [Pass 2] Verifying 5 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [285_2]: Leaf Eater (Freq: 7)
#    📈 Aggregating Frequencies: 16 + 7 = 23
#    🗑️  Removed 1 matches from the pool. New pool size: 93
# {'representative_question': {0: 'leaf eater', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'leaf eating caterpiller', 1: 'leaf eatter', 2: 'BEANS FLOWER EATING CATTERPILLAR', 3: 'leaf eating cutting in beans', 4: 'bean catterpiller', 5: nan}, 'false_positive': {0: 'leaf eating caterpiller', 1: nan, 2: 'BEANS FLOWER EATING CATTERPILLAR', 3: 'leaf eating cutting in beans', 4: 'bean catterpiller', 5: nan}, 'phase_2': {0: 'leaf eatter', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}}
#
# 🔍 Evaluating Reference [166_1]: What is the best way to manage fruit borer in beans? (Current Freq: 14)
#    Candidates remaining in pool: 92
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['166_6']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [166_6]: What is the best way to manage fruit borer in dolichos bean? (Freq: 12)
#    📈 Aggregating Frequencies: 14 + 12 = 26
#    🗑️  Removed 1 matches from the pool. New pool size: 91
# {'representative_question': {0: 'FRUIT BORER', 1: nan}, 'phase_1': {0: 'asked about fruit borer in dolichos bean', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about fruit borer in dolichos bean', 1: nan}}
#
# 🔍 Evaluating Reference [61_1]: Asked about plant protection in french bean (Current Freq: 14)
#    Candidates remaining in pool: 90
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['70_1', '70_3', '30_1', '158_9']
#    [Pass 2] Verifying 4 potential candidates...
#       -> [WARNING] JSON decoding failed in Pass 2.
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'FRUIT BORER', 1: nan}, 'phase_1': {0: 'asked about fruit borer in dolichos bean', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about fruit borer in dolichos bean', 1: nan}}
#
# 🔍 Evaluating Reference [70_1]: Asked about plant protection in dolichos bean (Current Freq: 13)
#    Candidates remaining in pool: 89
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['70_3', '30_1']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [70_3]: Asked about plant protection in dolichos bean (Freq: 8)
#       -> Matched [30_1]: Asked about Plant protection in dolicosbean (Freq: 8)
#    📈 Aggregating Frequencies: 13 + 16 = 29
#    🗑️  Removed 2 matches from the pool. New pool size: 87
# {'representative_question': {0: 'Asked about plant protection in  dolichos bean', 1: nan, 2: nan}, 'phase_1': {0: 'Asked about plant protection in dolichos bean', 1: 'Asked about Plant protection in dolicosbean', 2: nan}, 'false_positive': {0: nan, 1: nan, 2: nan}, 'phase_2': {0: 'Asked about plant protection in dolichos bean', 1: 'Asked about Plant protection in dolicosbean', 2: nan}}
#
# 🔍 Evaluating Reference [145_1]: Leaf-eating caterpillars on beans (Current Freq: 12)
#    Candidates remaining in pool: 86
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['146_2', '146_5', '318_4']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [146_2]: BEANS FLOWER EATING CATTERPILLAR (Freq: 1)
#       -> Matched [318_4]: Bean caterpillar (Freq: 1)
#    📈 Aggregating Frequencies: 12 + 2 = 14
#    🗑️  Removed 2 matches from the pool. New pool size: 84
# {'representative_question': {0: 'leaf eating caterpiller', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'BEANS FLOWER EATING CATTERPILLAR', 1: 'leaf eating cutting in beans', 2: 'bean catterpiller', 3: nan}, 'false_positive': {0: nan, 1: 'leaf eating cutting in beans', 2: nan, 3: nan}, 'phase_2': {0: 'BEANS FLOWER EATING CATTERPILLAR', 1: 'bean catterpiller', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [183_1]: What are the common thrips affecting beans and how can they be managed? (Current Freq: 12)
#    Candidates remaining in pool: 83
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['159_1', '2_7', '175_5', '175_6']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 4 verified matches.
#       -> Matched [159_1]: How can thrips be controlled in beans? (Freq: 2)
#       -> Matched [2_7]: Thripes management in beans crop (Freq: 2)
#       -> Matched [175_5]: How can thrips be managed in beans? (Freq: 1)
#       -> Matched [175_6]: What are the control measures for thrips in bean crops? (Freq: 1)
#    📈 Aggregating Frequencies: 12 + 6 = 18
#    🗑️  Removed 4 matches from the pool. New pool size: 79
# {'representative_question': {0: 'thrips', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'Asked about thrips control in beans', 1: 'THRIPES MANAGEMENT IN BEANS CROP', 2: 'asking for thrips management in beans', 3: 'thripes control measures in beans crop', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_2': {0: 'Asked about thrips control in beans', 1: 'THRIPES MANAGEMENT IN BEANS CROP', 2: 'asking for thrips management in beans', 3: 'thripes control measures in beans crop', 4: nan}}
#
# 🔍 Evaluating Reference [96_1]: Root Grub (Current Freq: 10)
#    Candidates remaining in pool: 78
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['308_6']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [308_6]: Rootgrub (Freq: 1)
#    📈 Aggregating Frequencies: 10 + 1 = 11
#    🗑️  Removed 1 matches from the pool. New pool size: 77
# {'representative_question': {0: 'root grub', 1: nan}, 'phase_1': {0: 'ROOTGRUB', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ROOTGRUB', 1: nan}}
#
# 🔍 Evaluating Reference [117_1]: Caterpillar bore the pods, feeds on seeds, and creates holes on pods (Current Freq: 9)
#    Candidates remaining in pool: 76
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'root grub', 1: nan}, 'phase_1': {0: 'ROOTGRUB', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ROOTGRUB', 1: nan}}
#
# 🔍 Evaluating Reference [208_1]: Aphid infestation in beans in the village of Avare (Current Freq: 7)
#    Candidates remaining in pool: 75
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['297_3']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'root grub', 1: nan}, 'phase_1': {0: 'ROOTGRUB', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ROOTGRUB', 1: nan}}
#
# 🔍 Evaluating Reference [52_1]: What are the common pests that affect Red gram and how can they be controlled? (Current Freq: 6)
#    Candidates remaining in pool: 74
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['132_1', '162_2', '158_7']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [162_2]: What are the common pests that affect redgram and how can they be controlled? (Freq: 3)
#       -> Matched [158_7]: Asked about Pest management in red gram (Freq: 1)
#    📈 Aggregating Frequencies: 6 + 4 = 10
#    🗑️  Removed 2 matches from the pool. New pool size: 72
# {'representative_question': {0: 'Asked about plant protection in  Red gram', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'REDGRAM PEST', 1: 'Asked about plant protection in  redgram', 2: 'Asked about Pest management in red gram', 3: nan}, 'false_positive': {0: 'REDGRAM PEST', 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Asked about plant protection in  redgram', 1: 'Asked about Pest management in red gram', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [196_1]: What is Hesraghata and how can it be managed in beans? (Current Freq: 6)
#    Candidates remaining in pool: 71
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in  Red gram', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'REDGRAM PEST', 1: 'Asked about plant protection in  redgram', 2: 'Asked about Pest management in red gram', 3: nan}, 'false_positive': {0: 'REDGRAM PEST', 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Asked about plant protection in  redgram', 1: 'Asked about Pest management in red gram', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [238_1]: What is the stem borer and how can it be managed in beans? (Current Freq: 6)
#    Candidates remaining in pool: 70
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in  Red gram', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'REDGRAM PEST', 1: 'Asked about plant protection in  redgram', 2: 'Asked about Pest management in red gram', 3: nan}, 'false_positive': {0: 'REDGRAM PEST', 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Asked about plant protection in  redgram', 1: 'Asked about Pest management in red gram', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [281_1]: How can I control leaf curl in beans? (Current Freq: 6)
#    Candidates remaining in pool: 69
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['295_4']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in  Red gram', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'REDGRAM PEST', 1: 'Asked about plant protection in  redgram', 2: 'Asked about Pest management in red gram', 3: nan}, 'false_positive': {0: 'REDGRAM PEST', 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Asked about plant protection in  redgram', 1: 'Asked about Pest management in red gram', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [338_1]: LAMDACYLOTHRIN INFORMATION (Current Freq: 5)
#    Candidates remaining in pool: 68
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in  Red gram', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'REDGRAM PEST', 1: 'Asked about plant protection in  redgram', 2: 'Asked about Pest management in red gram', 3: nan}, 'false_positive': {0: 'REDGRAM PEST', 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Asked about plant protection in  redgram', 1: 'Asked about Pest management in red gram', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [148_1]: What is the correct application method for dimethoate at 1 gram in 1 liter of water for bean crops? (Current Freq: 5)
#    Candidates remaining in pool: 67
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in  Red gram', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'REDGRAM PEST', 1: 'Asked about plant protection in  redgram', 2: 'Asked about Pest management in red gram', 3: nan}, 'false_positive': {0: 'REDGRAM PEST', 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Asked about plant protection in  redgram', 1: 'Asked about Pest management in red gram', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [243_1]: Beans pod borer and disease (Current Freq: 5)
#    Candidates remaining in pool: 66
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['232_2']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [232_2]: Borer in beans (Freq: 2)
#    📈 Aggregating Frequencies: 5 + 2 = 7
#    🗑️  Removed 1 matches from the pool. New pool size: 65
# {'representative_question': {0: 'Beans pod borer and disease', 1: nan}, 'phase_1': {0: 'borer in beans', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'borer in beans', 1: nan}}
#
# 🔍 Evaluating Reference [132_1]: Redgram Pest (Current Freq: 4)
#    Candidates remaining in pool: 64
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['237_3', '237_4', '297_3']
#    [Pass 2] Verifying 3 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Beans pod borer and disease', 1: nan}, 'phase_1': {0: 'borer in beans', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'borer in beans', 1: nan}}
#
# 🔍 Evaluating Reference [278_2]: Beans thrips (Current Freq: 4)
#    Candidates remaining in pool: 63
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Beans pod borer and disease', 1: nan}, 'phase_1': {0: 'borer in beans', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'borer in beans', 1: nan}}
#
# 🔍 Evaluating Reference [313_1]: How can black thrips be controlled in cowpea? (Current Freq: 4)
#    Candidates remaining in pool: 62
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Beans pod borer and disease', 1: nan}, 'phase_1': {0: 'borer in beans', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'borer in beans', 1: nan}}
#
# 🔍 Evaluating Reference [117_2]: Stem fly maggots are feeding on the basal portion of the bean plant, causing the plant to turn yellow and the stem to break at the damaged portion due to wind. (Current Freq: 4)
#    Candidates remaining in pool: 61
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['207_4']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [207_4]: Maggots are feeding on the basal portion of the bean plant's stem, causing the plant to turn yellow and the stem to break at the damaged area due to wind. (Freq: 3)
#    📈 Aggregating Frequencies: 4 + 3 = 7
#    🗑️  Removed 1 matches from the pool. New pool size: 60
# {'representative_question': {0: 'Stem flyMaggots scrape the basal portion of the stem Such plant yellow in colour breaking of the stem at damaged portion due to wind', 1: nan}, 'phase_1': {0: 'Maggots scrape the basal portion of the stem Such plant yellow in colour breaking of the stem at damaged portion due to wind', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Maggots scrape the basal portion of the stem Such plant yellow in colour breaking of the stem at damaged portion due to wind', 1: nan}}
#
# 🔍 Evaluating Reference [10_11]: Asked about Plant Protection in Broad Bean (Current Freq: 4)
#    Candidates remaining in pool: 59
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['158_8', '158_9', '237_4']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [158_8]: What are the common pests that affect broad beans and how can they be managed? (Freq: 1)
#       -> Matched [237_4]: Field beans pest (Freq: 1)
#    📈 Aggregating Frequencies: 4 + 2 = 6
#    🗑️  Removed 2 matches from the pool. New pool size: 57
# {'representative_question': {0: 'Asked about Plant Protection in  broad bean ', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'Asked about pest management in broad bean', 1: 'Asked about  pest management in french bean', 2: 'field beans pest', 3: nan}, 'false_positive': {0: nan, 1: 'Asked about  pest management in french bean', 2: nan, 3: nan}, 'phase_2': {0: 'Asked about pest management in broad bean', 1: 'field beans pest', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [275_1]: Asked for information on managing leaf hoppers in beans. (Current Freq: 3)
#    Candidates remaining in pool: 56
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Plant Protection in  broad bean ', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'Asked about pest management in broad bean', 1: 'Asked about  pest management in french bean', 2: 'field beans pest', 3: nan}, 'false_positive': {0: nan, 1: 'Asked about  pest management in french bean', 2: nan, 3: nan}, 'phase_2': {0: 'Asked about pest management in broad bean', 1: 'field beans pest', 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [185_1]: PEST IN CLUSTERBEAN (Current Freq: 3)
#    Candidates remaining in pool: 55
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['10_10', '237_3']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [10_10]: Asked about Plant Protection in Cluster Bean (Freq: 1)
#       -> Matched [237_3]: Cluster beans pest (Freq: 1)
#    📈 Aggregating Frequencies: 3 + 2 = 5
#    🗑️  Removed 2 matches from the pool. New pool size: 53
# {'representative_question': {0: 'PEST IN CLUSTERBEAN', 1: nan, 2: nan}, 'phase_1': {0: 'Asked about Plant Protection in  CLUSTERE BEAN', 1: 'cluster beans pest', 2: nan}, 'false_positive': {0: nan, 1: nan, 2: nan}, 'phase_2': {0: 'Asked about Plant Protection in  CLUSTERE BEAN', 1: 'cluster beans pest', 2: nan}}
#
# 🔍 Evaluating Reference [259_2]: What is the best way to manage root borers in beans? (Current Freq: 3)
#    Candidates remaining in pool: 52
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['232_1']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [232_1]: What is the best approach to manage the bean root borer? (Freq: 3)
#    📈 Aggregating Frequencies: 3 + 3 = 6
#    🗑️  Removed 1 matches from the pool. New pool size: 51
# {'representative_question': {0: 'root borer', 1: nan}, 'phase_1': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}}
#
# 🔍 Evaluating Reference [308_4]: Plant protection (Current Freq: 3)
#    Candidates remaining in pool: 50
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['67_1']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'root borer', 1: nan}, 'phase_1': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}}
#
# 🔍 Evaluating Reference [10_4]: Asked about plant protection in beans and ridgegourd (Current Freq: 3)
#    Candidates remaining in pool: 49
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'root borer', 1: nan}, 'phase_1': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}}
#
# 🔍 Evaluating Reference [134_1]: Asking about the management of hairy caterpillars in beans in Avare. (Current Freq: 3)
#    Candidates remaining in pool: 48
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'root borer', 1: nan}, 'phase_1': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}}
#
# 🔍 Evaluating Reference [295_2]: Adults and nymphs rasp the sap from leaves, causing small whitish streaks on the leaves. If the streaks are too numerous, the leaves turn whitish and the tips roll and dry up. What pest is this, and how can it be managed? (Current Freq: 3)
#    Candidates remaining in pool: 47
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'root borer', 1: nan}, 'phase_1': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}}
#
# 🔍 Evaluating Reference [148_2]: How should I apply 20 ml of Chlorpyriphos 20 EC per liter of water for bean pest management? (Current Freq: 3)
#    Candidates remaining in pool: 46
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'root borer', 1: nan}, 'phase_1': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKED ABOUT:BEANS ROOT BORER', 1: nan}}
#
# 🔍 Evaluating Reference [67_1]: Plant protection (Current Freq: 3)
#    Candidates remaining in pool: 45
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['60_2', '70_2', '332_1']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [60_2]: Asked about plant protection in cluster bean chemical recommendation (Freq: 2)
#       -> Matched [70_2]: Asked about Plant Protection in Dolichos Bean Control of Aphids (Freq: 2)
#       -> Matched [332_1]: Asked about Plant Protection in Beans and Arecanut (Freq: 2)
#    📈 Aggregating Frequencies: 3 + 6 = 9
#    🗑️  Removed 3 matches from the pool. New pool size: 42
# {'representative_question': {0: 'palnt protection', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'Asked about plant protection in   cluster bean chemical recommendation', 1: 'Asked about Plant Protection in  dolichos bean control of aphids', 2: 'Asked about Plant Proection in Beans and Arecanut', 3: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Asked about plant protection in   cluster bean chemical recommendation', 1: 'Asked about Plant Protection in  dolichos bean control of aphids', 2: 'Asked about Plant Proection in Beans and Arecanut', 3: nan}}
#
# 🔍 Evaluating Reference [16_2]: How can thrips be managed in cluster bean cultivation? (Current Freq: 2)
#    Candidates remaining in pool: 41
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'palnt protection', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'Asked about plant protection in   cluster bean chemical recommendation', 1: 'Asked about Plant Protection in  dolichos bean control of aphids', 2: 'Asked about Plant Proection in Beans and Arecanut', 3: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Asked about plant protection in   cluster bean chemical recommendation', 1: 'Asked about Plant Protection in  dolichos bean control of aphids', 2: 'Asked about Plant Proection in Beans and Arecanut', 3: nan}}
#
# 🔍 Evaluating Reference [281_2]: What are the control measures for leaf rollers in beans? (Current Freq: 2)
#    Candidates remaining in pool: 40
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['286_12']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [286_12]: What is a leaf roller and how can it be managed in bean crops? (Freq: 1)
#    📈 Aggregating Frequencies: 2 + 1 = 3
#    🗑️  Removed 1 matches from the pool. New pool size: 39
# {'representative_question': {0: 'Asked about control measures for leaf rollers in beans', 1: nan}, 'phase_1': {0: 'leaf roller', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'leaf roller', 1: nan}}
#
# 🔍 Evaluating Reference [149_1]: MANAGEMENT OF STEM FLY IN BEANS (Current Freq: 2)
#    Candidates remaining in pool: 38
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['10_8']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [10_8]: What is the best way to control Bean Stem Fly in my bean crop? (Freq: 1)
#    📈 Aggregating Frequencies: 2 + 1 = 3
#    🗑️  Removed 1 matches from the pool. New pool size: 37
# {'representative_question': {0: 'STEM FLY MANAGEMENT IN BEANS', 1: nan}, 'phase_1': {0: 'asked about plant protection BEANS STEM FLY', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection BEANS STEM FLY', 1: nan}}
#
# 🔍 Evaluating Reference [161_1]: French bean weed control (Current Freq: 2)
#    Candidates remaining in pool: 36
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'STEM FLY MANAGEMENT IN BEANS', 1: nan}, 'phase_1': {0: 'asked about plant protection BEANS STEM FLY', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection BEANS STEM FLY', 1: nan}}
#
# 🔍 Evaluating Reference [321_2]: Cluster bean weed (Current Freq: 2)
#    Candidates remaining in pool: 35
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'STEM FLY MANAGEMENT IN BEANS', 1: nan}, 'phase_1': {0: 'asked about plant protection BEANS STEM FLY', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection BEANS STEM FLY', 1: nan}}
#
# 🔍 Evaluating Reference [212_2]: How can I control storage pests in cowpea? (Current Freq: 2)
#    Candidates remaining in pool: 34
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'STEM FLY MANAGEMENT IN BEANS', 1: nan}, 'phase_1': {0: 'asked about plant protection BEANS STEM FLY', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection BEANS STEM FLY', 1: nan}}
#
# 🔍 Evaluating Reference [66_1]: Asked about the application of insecticide in Beans (Current Freq: 2)
#    Candidates remaining in pool: 33
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['337_22']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [337_22]: Beans pesticide (Freq: 1)
#    📈 Aggregating Frequencies: 2 + 1 = 3
#    🗑️  Removed 1 matches from the pool. New pool size: 32
# {'representative_question': {0: 'Asked about application of insecticide in Beans', 1: nan}, 'phase_1': {0: 'Beans pestiside', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Beans pestiside', 1: nan}}
#
# 🔍 Evaluating Reference [320_1]: Asked about flower drop in cluster bean (Current Freq: 2)
#    Candidates remaining in pool: 31
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about application of insecticide in Beans', 1: nan}, 'phase_1': {0: 'Beans pestiside', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Beans pestiside', 1: nan}}
#
# 🔍 Evaluating Reference [293_5]: What are the methods for controlling virus diseases in beans? (Current Freq: 2)
#    Candidates remaining in pool: 30
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about application of insecticide in Beans', 1: nan}, 'phase_1': {0: 'Beans pestiside', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Beans pestiside', 1: nan}}
#
# 🔍 Evaluating Reference [158_9]: Asked about pest management in french bean (Current Freq: 1)
#    Candidates remaining in pool: 29
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about application of insecticide in Beans', 1: nan}, 'phase_1': {0: 'Beans pestiside', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Beans pestiside', 1: nan}}
#
# ...
#
# 🔍 Evaluating Reference [134_4]: What is leaf rust in wheat and how can it be managed? (Current Freq: 4)
#    Candidates remaining in pool: 16
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Rust Disease management in Wheat', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'leaf rust', 1: 'ASKING FOR RUST MANAGEMENT IN WHEAT', 2: 'ASKING FOR Rust disease IN WHEAT', 3: 'asked about plant protection in yellow rust in wheat ', 4: nan}, 'false_positive': {0: 'leaf rust', 1: nan, 2: 'ASKING FOR Rust disease IN WHEAT', 3: 'asked about plant protection in yellow rust in wheat ', 4: nan}, 'phase_2': {0: 'ASKING FOR RUST MANAGEMENT IN WHEAT', 1: nan, 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [154_2]: Red spot found in wheat (Current Freq: 4)
#    Candidates remaining in pool: 15
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['155_1', '137_1', '134_6']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [137_1]: My wheat plants are showing signs of leaf reddening. What could be the cause and how should I manage it? (Freq: 2)
#    📈 Aggregating Frequencies: 4 + 2 = 6
#    🗑️  Removed 1 matches from the pool. New pool size: 14
# {'representative_question': {0: 'red spot found in wheat', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'red spot disease', 1: 'asked about wheat leaf reddening', 2: 'red leaf', 3: nan}, 'false_positive': {0: 'red spot disease', 1: nan, 2: 'red leaf', 3: nan}, 'phase_2': {0: 'asked about wheat leaf reddening', 1: nan, 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [63_3]: What are the common fungal diseases in wheat and how can they be managed? (Current Freq: 3)
#    Candidates remaining in pool: 13
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'red spot found in wheat', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'red spot disease', 1: 'asked about wheat leaf reddening', 2: 'red leaf', 3: nan}, 'false_positive': {0: 'red spot disease', 1: nan, 2: 'red leaf', 3: nan}, 'phase_2': {0: 'asked about wheat leaf reddening', 1: nan, 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [31_1]: What is the best management strategy for leaf spot disease in wheat? (Current Freq: 3)
#    Candidates remaining in pool: 12
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['11_10']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [11_10]: What is the best management strategy for controlling wheat leaf spot? (Freq: 1)
#    📈 Aggregating Frequencies: 3 + 1 = 4
#    🗑️  Removed 1 matches from the pool. New pool size: 11
# {'representative_question': {0: 'Asked about Leaf spot Disease management in Wheat', 1: nan}, 'phase_1': {0: 'ASKING ABOUT WHEAT LEAF SPOT MANAGEMENT', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKING ABOUT WHEAT LEAF SPOT MANAGEMENT', 1: nan}}
#
# 🔍 Evaluating Reference [155_1]: What is red spot disease in wheat and how can it be managed? (Current Freq: 3)
#    Candidates remaining in pool: 10
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Leaf spot Disease management in Wheat', 1: nan}, 'phase_1': {0: 'ASKING ABOUT WHEAT LEAF SPOT MANAGEMENT', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKING ABOUT WHEAT LEAF SPOT MANAGEMENT', 1: nan}}
#
# 🔍 Evaluating Reference [63_4]: What are the key disease management practices for wheat? (Current Freq: 2)
#    Candidates remaining in pool: 9
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Leaf spot Disease management in Wheat', 1: nan}, 'phase_1': {0: 'ASKING ABOUT WHEAT LEAF SPOT MANAGEMENT', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'ASKING ABOUT WHEAT LEAF SPOT MANAGEMENT', 1: nan}}
#
# 🔍 Evaluating Reference [114_1]: What are the symptoms and management practices for yellow rust in wheat? (Current Freq: 2)
#    Candidates remaining in pool: 8
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['1_3']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [1_3]: What are the best practices for managing yellow rust in wheat? (Freq: 1)
#    📈 Aggregating Frequencies: 2 + 1 = 3
#    🗑️  Removed 1 matches from the pool. New pool size: 7
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [145_1]: Brown leaf spot of Wheat: Infested leaf and grains with brown coloured egg shaped spots (Current Freq: 2)
#    Candidates remaining in pool: 6
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [159_4]: What is wilt in wheat and how can it be managed? (Current Freq: 1)
#    Candidates remaining in pool: 5
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [68_2]: My wheat plants are showing signs of stem rot. What could be the cause and how can I manage this disease? (Current Freq: 1)
#    Candidates remaining in pool: 4
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [127_2]: Wheat Stripe Rust and Yellow Rust - (Current Freq: 1)
#    Candidates remaining in pool: 3
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [28_2]: Wheat powdry mildew (Current Freq: 1)
#    Candidates remaining in pool: 2
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [108_2]: What is sheat blight and how can it be managed in wheat? (Current Freq: 1)
#    Candidates remaining in pool: 1
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# [INFO] Only 1 row left in category. Saving Reference [134_6] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: IRRELEVANT_CROP
# ======================================================================
# [INFO] Total rows to process in 'IRRELEVANT_CROP': 9
#
# 🔍 Evaluating Reference [19_1]: What are the key management practices for growing maize? (Current Freq: 21)
#    Candidates remaining in pool: 8
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [20_1]: Asked about Plant Protection in maize (Current Freq: 4)
#    Candidates remaining in pool: 7
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['20_2']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [132_1]: Asked about black wheat (Current Freq: 2)
#    Candidates remaining in pool: 6
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [4_6]: Asked about the sowing time for Wheat and Bengal gram. (Current Freq: 2)
#    Candidates remaining in pool: 5
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [20_2]: Asked about plant protection in diseases in maize (Current Freq: 1)
#    Candidates remaining in pool: 4
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'ASKING FOR Rust disease IN WHEAT', 1: nan}, 'phase_1': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about plant protection in yellow rust in wheat ', 1: nan}}
#
# 🔍 Evaluating Reference [20_3]: Asked about plant protection in sugarcane (Current Freq: 1)
#    Candidates remaining in pool: 3
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['9_9']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [9_9]: Asked about nutrient management in wheat and plant protection of sugarcane. (Freq: 1)
#    📈 Aggregating Frequencies: 1 + 1 = 2
#    🗑️  Removed 1 matches from the pool. New pool size: 2
# {'representative_question': {0: 'Asked about plant protection in    sugarcane', 1: nan}, 'phase_1': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}}
#
# 🔍 Evaluating Reference [9_5]: Asked about nutrient management in bengal gram and wheat (Current Freq: 1)
#    Candidates remaining in pool: 1
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in    sugarcane', 1: nan}, 'phase_1': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}}
#
# [INFO] Only 1 row left in category. Saving Reference [19_2] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Other
# ======================================================================
# [INFO] Total rows to process in 'Other': 4
#
# 🔍 Evaluating Reference [33_5]: Can you provide information on using USSD for wheat farming? (Current Freq: 2)
#    Candidates remaining in pool: 3
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in    sugarcane', 1: nan}, 'phase_1': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}}
#
# 🔍 Evaluating Reference [165_22]: Asked about growth promoter for wheat (Current Freq: 1)
#    Candidates remaining in pool: 2
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in    sugarcane', 1: nan}, 'phase_1': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}}
#
# 🔍 Evaluating Reference [165_21]: Asked about decomposition of wheat straw (Current Freq: 1)
#    Candidates remaining in pool: 1
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about plant protection in    sugarcane', 1: nan}, 'phase_1': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'asked about nutrient management in wheat and asked about plant protection of sugarcane ', 1: nan}}
#
# [INFO] Only 1 row left in category. Saving Reference [64_2] directly.
#
# ======================================================================
# 🎉 PROCESSING COMPLETE
# ======================================================================
# Original Dataset Size: 252
# Cleaned Dataset Size: 113
# Saved phase output: phase_data_wheat_faq.csv
# Saved final output: dedup_wheat_faq.csv

# %%
ref_phase1 = pd.DataFrame({
        'representative_question': ['HOW TO CONTROL THREAD WORMS IN PADDY FIELD', np.nan, np.nan, np.nan, np.nan, np.nan],                                                           
        'phase_1': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Threadworm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 'Threadworms in paddy', 'infomation regarding threadworm in paddy', 'thread worm in paddy'],                                                                                   
        'phase_1_id': ['39_1', '65_1', '66_1', '486_1', '482_11', '65_2'],
        'phase_2': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Threadworm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD','Threadworms in paddy', 'infomation regarding threadworm in paddy', np.nan],               
        'phase_2_id': ['39_1', '65_1', '66_1', '486_1', '482_11', np.nan],                   
    })                                                                                       
   
ref_phase2 = pd.DataFrame({                                                                
        'representative_question': ['BEST FERTILIZER FOR WHEAT CROP', np.nan, np.nan,np.nan],
        'phase_1': ['fertilizer for wheat', 'which fertilizer for wheat', 'nutrient management in wheat', 'manure for wheat crop'],                                            
        'phase_1_id': ['10_1', '11_1', '12_1', '13_1'],
        'phase_2': ['fertilizer for wheat', 'which fertilizer for wheat', 'nutrient management in wheat', np.nan],                                                             
        'phase_2_id': ['10_1', '11_1', '12_1', np.nan],
    })                                                                                       
                                                            
phase_data = []                                                                            
   
for ref_phase in [ref_phase1, ref_phase2]:                                                 
      phase_2_ids = set(ref_phase['phase_2_id'].dropna())   
      removed_mask = ~ref_phase['phase_1_id'].isin(phase_2_ids)
      ref_phase['false_positive'] = ref_phase.loc[removed_mask, 'phase_1']                   
      false_positives = ref_phase['false_positive'].dropna()
      ref_phase['false_positive'] = false_positives                                          
      ref_phase.drop(columns=['phase_1_id', 'phase_2_id'], inplace=True)                     
      ref_phase = ref_phase[['representative_question', 'phase_1', 'false_positive','phase_2']]                                                                                
      ref_phase = pd.concat([ref_phase, pd.DataFrame([{}])], ignore_index=True)
      phase_data.append(ref_phase)                                                           
                                                            
pd.concat(phase_data, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 ref_phase1 = pd.DataFrame({
# ----> 2         'representative_question': ['HOW TO CONTROL THREAD WORMS IN PADDY FIELD', np.nan, np.nan, np.nan, np.nan, np.nan],
#       3         'phase_1': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Threadworm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 'Threadworms in paddy', 'infomation regarding threadworm in paddy', 'thread worm in paddy'],
#       4         'phase_1_id': ['39_1', '65_1', '66_1', '486_1', '482_11', '65_2'],
#       5         'phase_2': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Threadworm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD','Threadworms in paddy', 'infomation regarding threadworm in paddy', np.nan],
#       6         'phase_2_id': ['39_1', '65_1', '66_1', '486_1', '482_11', np.nan],
#       7     })
#       9 ref_phase2 = pd.DataFrame({
#      10         'representative_question': ['BEST FERTILIZER FOR WHEAT CROP', np.nan, np.nan,np.nan],
#      11         'phase_1': ['fertilizer for wheat', 'which fertilizer for wheat', 'nutrient management in wheat', 'manure for wheat crop'],
#    (...)     14         'phase_2_id': ['10_1', '11_1', '12_1', np.nan],
#      15     })
#      17 phase_data = []
#
# NameError: name 'np' is not defined
