# %%
import requests

def gemma_4_26b_it_completion(prompt, max_tokens=512, temperature=0.0, top_p=0.95, stop=None):
    """
    Wrapper function to call the google/gemma-3-12b-it model, exposed via OpenAI-style API.

    Args:
        prompt (str): The prompt to send to the model.
        max_tokens (int): The maximum number of tokens to generate.
        temperature (float): Sampling temperature.
        top_p (float): Nucleus sampling probability.
        stop (list or str, optional): Stop sequence(s).

    Returns:
        str: The model's generated text completion.
    """
    api_url = "http://100.100.108.44:8013/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    data = {
        "model": "google/gemma-4-26B-A4B-it",
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": max_tokens,
        "temperature": temperature,
        "top_p": top_p,
    }
    if stop is not None:
        data["stop"] = stop

    response = requests.post(api_url, headers=headers, json=data)
    if response.status_code == 200:
        completion = response.json()
        return completion['choices'][0]['message']['content']
    else:
        raise RuntimeError(f"Failed to fetch completion: {response.status_code} - {response.text}")

# %%
import pandas as pd
import re
import json
from tqdm.auto import tqdm

def deduplicate_and_aggregate(df, text_col='Generated_Question', batch_size=100):
    """
    Iterates through categories, finds similar questions using LLM, 
    aggregates 'raw_frequency', and removes duplicates with full logging.
    """
    # Ensure raw_frequency is numeric to allow summing
    df['raw_frequency'] = pd.to_numeric(df['raw_frequency'], errors='coerce').fillna(0)

    phase_data = []
    final_cleaned_data = []
    categories = df['Generated_Category'].unique()

    # Outer progress bar for categories
    category_pbar = tqdm(categories, desc="Processing Categories", position=0)

    for category in category_pbar:
        # Update progress bar postfix to show current category
        category_pbar.set_postfix({"Current": category})
        
        tqdm.write(f"\n{'='*70}")
        tqdm.write(f"🚀 STARTING CATEGORY: {category}")
        tqdm.write(f"{'='*70}")
        
        # Isolate rows for the current category
        cat_df = df[df['Generated_Category'] == category].copy()
        total_initial = len(cat_df)
        tqdm.write(f"[INFO] Total rows to process in '{category}': {total_initial}")
        
        # Loop until no rows are left in this category's pool
        while not cat_df.empty:
            # Pop the first row to act as the reference
            ref_phase = []
            reference_row = cat_df.iloc[0].copy()
            ref_phase.append({                                                                     
                      'representative_question': reference_row['representative_question']
                  })
            ref_id = reference_row['unique_q_id']
            ref_question = reference_row[text_col]
            current_freq = reference_row['raw_frequency']
            
            # The candidates are all OTHER rows in this category
            remaining_df = cat_df.iloc[1:].reset_index(drop=True)
            
            if remaining_df.empty:
                tqdm.write(f"\n[INFO] Only 1 row left in category. Saving Reference [{ref_id}] directly.")
                final_cleaned_data.append(reference_row.to_dict())
                break
                
            tqdm.write(f"\n🔍 Evaluating Reference [{ref_id}]: {ref_question} (Current Freq: {current_freq})")
            tqdm.write(f"   Candidates remaining in pool: {len(remaining_df)}")
            
            # Find matches using the 2-pass LLM approach
            matched_ids, ref_phase = _get_verified_matches(reference_row, remaining_df, text_col, batch_size, ref_phase)
            
            if matched_ids:
                # Isolate the matched rows
                matches_df = remaining_df[remaining_df['unique_q_id'].isin(matched_ids)]

                ## Adding info to ref_phase
                ref_phase = pd.concat([                                                                            
                            ref_phase,
                            matches_df[['representative_question', 'unique_q_id']].rename(columns={                 
                                    'representative_question': 'phase_2',                                      
                                    'unique_q_id': 'phase_2_id'
                            }).reset_index(drop=True)                                                          
                            ], axis=1)

                
                phase_2_ids = set(ref_phase['phase_2_id'].dropna())                                                                                   
                removed_mask = ~ref_phase['phase_1_id'].isin(phase_2_ids)                                                                             
                ref_phase['false_positive'] = ref_phase.loc[removed_mask, 'phase_1']
                false_positives = ref_phase['false_positive'].dropna().reset_index(drop=True)                                                         
                ref_phase['false_positive'] = false_positives    
                ref_phase.drop(columns=['phase_1_id', 'phase_2_id'], inplace=True)
                ref_phase = ref_phase[['representative_question', 'phase_1', 'false_positive', 'phase_2']]
                ref_phase = pd.concat([ref_phase, pd.DataFrame([{}])], ignore_index=True)

                phase_data.append(ref_phase)
                
                # Sum the raw_frequency of the matches
                summed_frequency = matches_df['raw_frequency'].sum()
    
                tqdm.write(f"   ✅ SUCCESS: Found {len(matched_ids)} verified matches.")
                for _, m_row in matches_df.iterrows():
                    tqdm.write(f"      -> Matched [{m_row['unique_q_id']}]: {m_row[text_col]} (Freq: {m_row['raw_frequency']})")
                    
                tqdm.write(f"   📈 Aggregating Frequencies: {current_freq} + {summed_frequency} = {current_freq + summed_frequency}")
                    
                # Add it to the reference row
                reference_row['raw_frequency'] += summed_frequency
                    
                # Remove matched rows from the remaining pool
                cat_df = remaining_df[~remaining_df['unique_q_id'].isin(matched_ids)].reset_index(drop=True)
                tqdm.write(f"   🗑️  Removed {len(matched_ids)} matches from the pool. New pool size: {len(cat_df)}")
                
            else:
                tqdm.write("   ❌ No matches found. Moving to next row.")
                # No matches, so the next pool is just the remaining items
                cat_df = remaining_df
                    
                # Save the updated reference row to our final list
                final_cleaned_data.append(reference_row.to_dict())

            print(phase_data[-1].to_dict())

    tqdm.write(f"\n{'='*70}\n🎉 PROCESSING COMPLETE\n{'='*70}")
    tqdm.write(f"Original Dataset Size: {len(df)}")
    tqdm.write(f"Cleaned Dataset Size: {len(final_cleaned_data)}")
    
    # Return the clean, aggregated DataFrame
    return pd.DataFrame(final_cleaned_data), pd.concat(phase_data, ignore_index=True)


def _get_verified_matches(reference_row, candidate_df, text_col, batch_size, ref_phase):
    """
    Helper function running the 2-pass LLM matching logic with batch-level progress and logging.
    """
    original_id = reference_row['unique_q_id']
    original_question = reference_row[text_col]
    
    all_candidate_ids = []
    
    # Calculate total batches for tqdm
    total_batches = (len(candidate_df) + batch_size - 1) // batch_size

    # --- PASS 1: Batch Initial Search ---
    tqdm.write("   [Pass 1] Scanning for initial candidates...")
    
    # Inner progress bar for batches (leave=False hides it after it finishes)
    for start in tqdm(range(0, len(candidate_df), batch_size), total=total_batches, desc="Pass 1 Batches", leave=False):
        batch = candidate_df.iloc[start:start+batch_size]

        batch_text = "\n".join([
            f"{row['unique_q_id']}: {row[text_col]}"
            for _, row in batch.iterrows()
        ])

        prompt = f"""
You are given one reference question and a list of candidate questions.
Task: Return ONLY the IDs of questions that exact same or rephrased to the reference question.
Rules:
- Output ONLY a JSON list of matching IDs
- No explanation
- If none match, return []

Reference:
{original_id}: {original_question}

Candidates:
{batch_text}

Output:
"""
        # Call your LLM here
        response = gemma_4_26b_it_completion(prompt, max_tokens=2000, temperature=0.0)

        match = re.search(r'\[.*\]', response, re.DOTALL)
        if match:
            try:
                found_in_batch = json.loads(match.group(0))
                if found_in_batch:
                    tqdm.write(f"      -> Batch flagged {len(found_in_batch)} potential IDs: {found_in_batch}")
                all_candidate_ids.extend(found_in_batch)
            except json.JSONDecodeError:
                tqdm.write("      -> [WARNING] JSON decoding failed in Pass 1 for a batch.")

    ref_phase = pd.DataFrame(ref_phase)
    
    # --- PASS 2: Verification ---
    if not all_candidate_ids:
        return [], ref_phase
    
    tqdm.write(f"   [Pass 2] Verifying {len(all_candidate_ids)} potential candidates...")
    candidate_rows = candidate_df[candidate_df['unique_q_id'].isin(all_candidate_ids)]

    #adding info to ref_phase
    ref_phase = pd.concat([                                                                            
                ref_phase,
                candidate_rows[['representative_question', 'unique_q_id']].rename(columns={                 
                                        'representative_question': 'phase_1',                                      
                                        'unique_q_id': 'phase_1_id'
                                }).reset_index(drop=True)                                                          
                                ], axis=1)
    
    verification_batch_text = "\n".join([
        f"{row['unique_q_id']}: {row[text_col]}"
        for _, row in candidate_rows.iterrows()
    ])

    verification_prompt = f"""
Task: Strictly review these candidates. Remove any questions that are NOT the exact same or a direct rephrase.
Rules: Output ONLY a JSON list of matching IDs. No explanation. If none match, return [].

Reference:
{original_id}: {original_question}

Candidates to Verify:
{verification_batch_text}

Output:
"""
    verification_response = gemma_4_26b_it_completion(verification_prompt, max_tokens=2000, temperature=0.0)

    final_matched_ids = []
    final_match = re.search(r'\[.*\]', verification_response, re.DOTALL)
    if final_match:
        try:
            final_matched_ids = json.loads(final_match.group(0))
        except json.JSONDecodeError:
            tqdm.write("      -> [WARNING] JSON decoding failed in Pass 2.")

    # Filter out any hallucinated IDs that weren't actually in the candidates pool
    final_matched_ids = [mid for mid in final_matched_ids if mid in all_candidate_ids]

    return final_matched_ids, ref_phase

# %%
from pathlib import Path
import pandas as pd

crops_folder = Path('../outputs/repair/final')


for csv_file in crops_folder.glob("*.csv"):
    print(f"Processing: {csv_file.name}")

    # Create output filename
    output_name_phase= f"phase_data_{csv_file.name}"
    output_name_final = f"dedup_{csv_file.name}"
    
    output_path_phase = crops_folder / output_name_phase
    output_path_final = crops_folder / output_name_final
    
    # Read CSV
    df = pd.read_csv(csv_file, low_memory=False)

    # Apply your function
    df, df1 = deduplicate_and_aggregate(df)

    df1.to_csv(output_path_phase, index=False)
        
    # Filter
    df = df[df['answer_label'] != "(unclassified)"]

    # Save
    df.to_csv(output_path_final, index=False)

    print(f"Saved phase output: {output_name_phase}")
    print(f"Saved final output: {output_name_final}")
# Out:
# Processing: paddy_faq.csv
# Processing Categories:   0%|          | 0/10 [00:00<?, ?it/s]
# ======================================================================
# 🚀 STARTING CATEGORY: Pest and Weed Management
# ======================================================================
# [INFO] Total rows to process in 'Pest and Weed Management': 1
#
# [INFO] Only 1 row left in category. Saving Reference [273_1] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Pest
# ======================================================================
# [INFO] Total rows to process in 'Pest': 153
#
# 🔍 Evaluating Reference [53_1]: HOW TO CONTROL THREAD WORMS IN PADDY FIELD (Current Freq: 222)
#    Candidates remaining in pool: 152
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 5 potential IDs: ['39_1', '65_1', '66_1', '486_1', '482_11']
#       -> Batch flagged 1 potential IDs: ['65_2']
#    [Pass 2] Verifying 6 potential candidates...
#    ✅ SUCCESS: Found 5 verified matches.
#       -> Matched [39_1]: CONTROL OF THREADWORMS IN PADDY (Freq: 14)
#       -> Matched [65_1]: What is the best approach to manage the thread worm problem in paddy crops? (Freq: 12)
#       -> Matched [66_1]: Regarding the attack of thread worms in paddy field (Freq: 6)
#       -> Matched [486_1]: Threadworms in paddy (Freq: 5)
#       -> Matched [482_11]: Information regarding threadworm in paddy (Freq: 2)
#    📈 Aggregating Frequencies: 222 + 39 = 261
#    🗑️  Removed 5 matches from the pool. New pool size: 147
# {'representative_question': {0: 'HOW TO CONTROL THREAD WORMS IN PADDY FIELD ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'CONTROL  OF    THREADWORMS IN  PADDY ', 1: 'Farmer asked a query regarding Thread worm problem in an paddy crop', 2: 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 3: 'Threadworms in paddy', 4: 'infomation regarding threadworm in paddy', 5: 'thread worm in paddy '}, 'phase_1_id': {0: '39_1', 1: '65_1', 2: '66_1', 3: '486_1', 4: '482_11', 5: '65_2'}, 'phase_2': {0: 'CONTROL  OF    THREADWORMS IN  PADDY ', 1: 'Farmer asked a query regarding Thread worm problem in an paddy crop', 2: 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 3: 'Threadworms in paddy', 4: 'infomation regarding threadworm in paddy', 5: nan}, 'phase_2_id': {0: '39_1', 1: '65_1', 2: '66_1', 3: '486_1', 4: '482_11', 5: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}}
#
# 🔍 Evaluating Reference [322_1]: What are the key plant protection measures for paddy? (Current Freq: 49)
#    Candidates remaining in pool: 146
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 6 potential IDs: ['333_1', '323_2', '423_1', '374_10', '271_7', '271_1']
#       -> Batch flagged 3 potential IDs: ['486_6', '423_6', '423_5']
#    [Pass 2] Verifying 9 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL THREAD WORMS IN PADDY FIELD ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'CONTROL  OF    THREADWORMS IN  PADDY ', 1: 'Farmer asked a query regarding Thread worm problem in an paddy crop', 2: 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 3: 'Threadworms in paddy', 4: 'infomation regarding threadworm in paddy', 5: 'thread worm in paddy '}, 'phase_1_id': {0: '39_1', 1: '65_1', 2: '66_1', 3: '486_1', 4: '482_11', 5: '65_2'}, 'phase_2': {0: 'CONTROL  OF    THREADWORMS IN  PADDY ', 1: 'Farmer asked a query regarding Thread worm problem in an paddy crop', 2: 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 3: 'Threadworms in paddy', 4: 'infomation regarding threadworm in paddy', 5: nan}, 'phase_2_id': {0: '39_1', 1: '65_1', 2: '66_1', 3: '486_1', 4: '482_11', 5: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}}
#
# 🔍 Evaluating Reference [285_1]: Information regarding control of yellow leaves in paddy (Current Freq: 44)
#    Candidates remaining in pool: 145
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['93_5', '93_4', '463_2']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [93_5]: How to control yellowing and drying of paddy crop? (Freq: 1)
#       -> Matched [93_4]: How to control yellowing and drying of paddy? (Freq: 1)
#       -> Matched [463_2]: Information regarding the control of yellow leaves in paddy. (Freq: 1)
#    📈 Aggregating Frequencies: 44 + 3 = 47
#    🗑️  Removed 3 matches from the pool. New pool size: 142
# {'representative_question': {0: 'information regarding control of yellow leaves in paddy', 1: nan, 2: nan}, 'phase_1': {0: 'how to control yellowing and drying of paddy crop ', 1: 'how to control yellow and drying of paddy', 2: 'information regarding control of yelowness leaves in pSSY'}, 'phase_1_id': {0: '93_5', 1: '93_4', 2: '463_2'}, 'phase_2': {0: 'how to control yellowing and drying of paddy crop ', 1: 'how to control yellow and drying of paddy', 2: 'information regarding control of yelowness leaves in pSSY'}, 'phase_2_id': {0: '93_5', 1: '93_4', 2: '463_2'}, 'false_positive': {0: nan, 1: nan, 2: nan}}
#
# 🔍 Evaluating Reference [203_1]: How can I control leaf folder in paddy? (Current Freq: 39)
#    Candidates remaining in pool: 141
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['158_3']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [158_3]: What is the problem of leaf folder in paddy and how can it be managed? (Freq: 2)
#    📈 Aggregating Frequencies: 39 + 2 = 41
#    🗑️  Removed 1 matches from the pool. New pool size: 140
# {'representative_question': {0: 'CONTROL FROM LEAF FOLDER IN PADDY'}, 'phase_1': {0: 'problem of leaf folder in paddy '}, 'phase_1_id': {0: '158_3'}, 'phase_2': {0: 'problem of leaf folder in paddy '}, 'phase_2_id': {0: '158_3'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [160_1]: HOW TO CONTROL SHEATH BLIGHT IN PADDY (Current Freq: 38)
#    Candidates remaining in pool: 139
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['422_1', '172_2']
#       -> Batch flagged 1 potential IDs: ['161_6']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [422_1]: HOW TO CONTROL SHEATH BLIGHT IN PADDY (Freq: 3)
#       -> Matched [172_2]: Information regarding control of sheath blight in paddy. (Freq: 1)
#       -> Matched [161_6]: What is the problem of Sheath Blight in Paddy and how can it be managed? (Freq: 1)
#    📈 Aggregating Frequencies: 38 + 5 = 43
#    🗑️  Removed 3 matches from the pool. New pool size: 136
# {'representative_question': {0: 'HOW TO CONTROL SHEATH BLIGHT IN PADDY ', 1: nan, 2: nan}, 'phase_1': {0: 'HOW TO CONTROL SHEALTH  IN PADDY ', 1: 'information regarding control of sheath root in paddy', 2: 'regarding problem of Sheath Blight '}, 'phase_1_id': {0: '422_1', 1: '172_2', 2: '161_6'}, 'phase_2': {0: 'HOW TO CONTROL SHEALTH  IN PADDY ', 1: 'information regarding control of sheath root in paddy', 2: 'regarding problem of Sheath Blight '}, 'phase_2_id': {0: '422_1', 1: '172_2', 2: '161_6'}, 'false_positive': {0: nan, 1: nan, 2: nan}}
#
# 🔍 Evaluating Reference [110_1]: How can stem borers be controlled in paddy? (Current Freq: 24)
#    Candidates remaining in pool: 135
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 7 potential IDs: ['118_1', '118_6', '110_2', '95_1', '95_3', '208_2', '118_4']
#    [Pass 2] Verifying 7 potential candidates...
#    ✅ SUCCESS: Found 4 verified matches.
#       -> Matched [118_1]: Regarding stem borer in paddy (Freq: 23)
#       -> Matched [118_6]: Regarding the stem borer in paddy (Freq: 7)
#       -> Matched [110_2]: HOW TO CONTROL STEM BORER IN PADDY (Freq: 6)
#       -> Matched [208_2]: HOW TO CONTROL STEM BORER IN RICE (Freq: 1)
#    📈 Aggregating Frequencies: 24 + 37 = 61
#    🗑️  Removed 4 matches from the pool. New pool size: 131
# {'representative_question': {0: 'CONTROL OF STEM BORER IN PADDY ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}, 'phase_1': {0: 'Regarding stem borer in paddy', 1: 'regarding stem borer attack in paddy', 2: 'Regarding the stem borer in paddy', 3: 'HOW TO CONTROL STEM BORER IN PADDY ', 4: 'REGARDING STEM BORER  ATTACK IN PADDY ', 5: 'HOW TO CONTROL STEM BORER IN RICE ', 6: 'Regarding stem borer management in transplanted paddy'}, 'phase_1_id': {0: '118_1', 1: '95_1', 2: '118_6', 3: '110_2', 4: '95_3', 5: '208_2', 6: '118_4'}, 'phase_2': {0: 'Regarding stem borer in paddy', 1: 'Regarding the stem borer in paddy', 2: 'HOW TO CONTROL STEM BORER IN PADDY ', 3: 'HOW TO CONTROL STEM BORER IN RICE ', 4: nan, 5: nan, 6: nan}, 'phase_2_id': {0: '118_1', 1: '118_6', 2: '110_2', 3: '208_2', 4: nan, 5: nan, 6: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}}
#
# 🔍 Evaluating Reference [266_7]: When should I spray for pests in paddy? (Current Freq: 19)
#    Candidates remaining in pool: 130
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['154_2']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [154_2]: What are the appropriate times and methods for applying insecticides and fungicides in paddy fields? (Freq: 1)
#    📈 Aggregating Frequencies: 19 + 1 = 20
#    🗑️  Removed 1 matches from the pool. New pool size: 129
# {'representative_question': {0: 'spray in paddy '}, 'phase_1': {0: 'insecticide and fungicide application'}, 'phase_1_id': {0: '154_2'}, 'phase_2': {0: 'insecticide and fungicide application'}, 'phase_2_id': {0: '154_2'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [92_1]: What is the correct method for spraying to control pests in paddy fields? (Current Freq: 17)
#    Candidates remaining in pool: 128
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['483_4']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'spray in paddy '}, 'phase_1': {0: 'insecticide and fungicide application'}, 'phase_1_id': {0: '154_2'}, 'phase_2': {0: 'insecticide and fungicide application'}, 'phase_2_id': {0: '154_2'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [271_7]: What are the common insects that affect paddy crops and how can they be managed? (Current Freq: 17)
#    Candidates remaining in pool: 127
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 6 potential IDs: ['334_1', '333_1', '271_1', '374_10', '486_6', '423_6']
#       -> Batch flagged 2 potential IDs: ['423_5', '474_3']
#    [Pass 2] Verifying 8 potential candidates...
#    ✅ SUCCESS: Found 7 verified matches.
#       -> Matched [334_1]: Information regarding control of insect in paddy (Freq: 15)
#       -> Matched [333_1]: How can I control insect pests in paddy? (Freq: 7)
#       -> Matched [271_1]: What are the common insect pests in paddy and how can they be managed? (Freq: 6)
#       -> Matched [374_10]: What are the common pests that attack paddy and how can they be managed? (Freq: 1)
#       -> Matched [486_6]: What are the common pests affecting paddy and how can they be managed? (Freq: 1)
#       -> Matched [423_6]: HOW TO CONTROL INSECTS PESTS ON PADDY CROPS (Freq: 1)
#       -> Matched [423_5]: HOW TO CONTROL INSECTS PESTS IN PADDY? (Freq: 1)
#    📈 Aggregating Frequencies: 17 + 32 = 49
#    🗑️  Removed 7 matches from the pool. New pool size: 120
# {'representative_question': {0: 'regarding insect in paddy crop ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}, 'phase_1': {0: 'information regarding control of insect in paddy', 1: 'CONTROL FROM INSECT IN PADDY', 2: 'INSECT PEST IN PADDY', 3: 'Farmer asked the query regarding attack of rice hispa and grasshopper attack in paddy ', 4: 'FER IN PADDY', 5: 'HOW TO CONTROL INSECTS PESTS ON PADDY CROPS ', 6: 'HOW TO CONTROL INSECTS PEST O PADDY ', 7: 'INSECTS IN RICE'}, 'phase_1_id': {0: '334_1', 1: '333_1', 2: '271_1', 3: '374_10', 4: '486_6', 5: '423_6', 6: '423_5', 7: '474_3'}, 'phase_2': {0: 'information regarding control of insect in paddy', 1: 'CONTROL FROM INSECT IN PADDY', 2: 'INSECT PEST IN PADDY', 3: 'Farmer asked the query regarding attack of rice hispa and grasshopper attack in paddy ', 4: 'FER IN PADDY', 5: 'HOW TO CONTROL INSECTS PESTS ON PADDY CROPS ', 6: 'HOW TO CONTROL INSECTS PEST O PADDY ', 7: nan}, 'phase_2_id': {0: '334_1', 1: '333_1', 2: '271_1', 3: '374_10', 4: '486_6', 5: '423_6', 6: '423_5', 7: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}}
#
# 🔍 Evaluating Reference [266_5]: What sprays are recommended for paddy? (Current Freq: 15)
#    Candidates remaining in pool: 119
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['483_4']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [483_4]: What insecticides are suitable for controlling pests in paddy fields? (Freq: 5)
#    📈 Aggregating Frequencies: 15 + 5 = 20
#    🗑️  Removed 1 matches from the pool. New pool size: 118
# {'representative_question': {0: 'SPRAY FOR PADDY'}, 'phase_1': {0: 'insecticide for paddy'}, 'phase_1_id': {0: '483_4'}, 'phase_2': {0: 'insecticide for paddy'}, 'phase_2_id': {0: '483_4'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [316_1]: What should I do if there is an insect attack in my paddy field? (Current Freq: 12)
#    Candidates remaining in pool: 117
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 7 potential IDs: ['289_1', '436_1', '271_2', '271_4', '271_5', '271_6', '271_3']
#       -> [WARNING] JSON decoding failed in Pass 1 for a batch.
#    [Pass 2] Verifying 7 potential candidates...
#    ✅ SUCCESS: Found 7 verified matches.
#       -> Matched [289_1]: Regarding insect attack in rice (Freq: 3)
#       -> Matched [271_2]: Information regarding insects in paddy. (Freq: 3)
#       -> Matched [436_1]: Regarding the problem of insects in paddy fields (Freq: 2)
#       -> Matched [271_6]: Regarding the insect pest management in paddy? (Freq: 1)
#       -> Matched [271_5]: Regarding the insect pest on paddy (Freq: 1)
#       -> Matched [271_4]: Regarding insect problem in paddy (Freq: 1)
#       -> Matched [271_3]: PEST ATTACK ON PADDY (Freq: 1)
#    📈 Aggregating Frequencies: 12 + 12 = 24
#    🗑️  Removed 7 matches from the pool. New pool size: 110
# {'representative_question': {0: 'insect attack in paddy', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}, 'phase_1': {0: 'REGARDING INSECT ATTACK IN RICE', 1: 'info regarding insect in paddy', 2: 'REGARDING PROBLEM OF INSECTS IN CULTIVABLE LAND', 3: 'Regarding the insect pest management in paddy?', 4: 'REGARDING THE INSECT PEST ON PADDY', 5: 'REGARDING INSECT PROBLEM IN PADDY', 6: 'PEST ATTCAK ON PADDY'}, 'phase_1_id': {0: '289_1', 1: '271_2', 2: '436_1', 3: '271_6', 4: '271_5', 5: '271_4', 6: '271_3'}, 'phase_2': {0: 'REGARDING INSECT ATTACK IN RICE', 1: 'info regarding insect in paddy', 2: 'REGARDING PROBLEM OF INSECTS IN CULTIVABLE LAND', 3: 'Regarding the insect pest management in paddy?', 4: 'REGARDING THE INSECT PEST ON PADDY', 5: 'REGARDING INSECT PROBLEM IN PADDY', 6: 'PEST ATTCAK ON PADDY'}, 'phase_2_id': {0: '289_1', 1: '271_2', 2: '436_1', 3: '271_6', 4: '271_5', 5: '271_4', 6: '271_3'}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}}
#
# 🔍 Evaluating Reference [400_1]: HOW TO CONTROL GRASSHOPPER IN PADDY (Current Freq: 12)
#    Candidates remaining in pool: 109
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 13 potential IDs: ['365_1', '366_1', '464_1', '401_1', '445_2', '449_1', '374_5', '401_2', '374_3', '374_7', '477_2', '462_2', '463_1']
#       -> [WARNING] JSON decoding failed in Pass 1 for a batch.
#    [Pass 2] Verifying 13 potential candidates...
#    ✅ SUCCESS: Found 10 verified matches.
#       -> Matched [365_1]: Regarding grass hopper in paddy (Freq: 9)
#       -> Matched [464_1]: CONTROL OF GRASHOPPER IN PADDY (Freq: 8)
#       -> Matched [401_1]: CONTROL OF GRASSHOPPERS IN PADDY (Freq: 8)
#       -> Matched [445_2]: How can I control grasshoppers in rice? (Freq: 7)
#       -> Matched [449_1]: Regarding grasshopper attack in paddy (Freq: 5)
#       -> Matched [374_5]: What should I do if my paddy field is affected by grasshoppers? (Freq: 4)
#       -> Matched [401_2]: How can I manage grasshoppers in my paddy crop? (Freq: 3)
#       -> Matched [462_2]: How can I control the gross hopper pest in my paddy field? (Freq: 1)
#       -> Matched [374_7]: What should I do if my paddy field is being attacked by grasshoppers? (Freq: 1)
#       -> Matched [463_1]: How can I control grosshoppers in my paddy field? (Freq: 1)
#    📈 Aggregating Frequencies: 12 + 47 = 59
#    🗑️  Removed 10 matches from the pool. New pool size: 99
# {'representative_question': {0: 'HOW TO CONTROL GRASSHOPPER IN PADDY ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan, 9: nan, 10: nan, 11: nan, 12: nan}, 'phase_1': {0: 'REGARDING GRASS HOPPER IN PADDY', 1: 'REGARDING HOPPER INFESTATION IN PADDY FIELD', 2: 'CONTROL   OF GRASHOPPER   IN   PADDY    ', 3: 'COMTROL OF  GRASSHOPPER  IN    PADDY   ', 4: 'CONTROL FOR GRASSHOPPER IN RICE ', 5: 'REGARDING GRASSHOPPER ATTACK IN PADDY', 6: 'Farmer asked the query regarding grasshopper attack in paddy', 7: 'grasshopper in paddy crop', 8: 'Farmer asked a query regarding grasshopper problem in an paddy crop', 9: 'regarding control of gross hopper ', 10: 'Farmer asked query regarding Attack of grasshopper in paddy', 11: 'REGARDING GRASSHOPPER PROBLEM IN THE RICE FIELD', 12: 'Regarding control of grosshopper '}, 'phase_1_id': {0: '365_1', 1: '366_1', 2: '464_1', 3: '401_1', 4: '445_2', 5: '449_1', 6: '374_5', 7: '401_2', 8: '374_3', 9: '462_2', 10: '374_7', 11: '477_2', 12: '463_1'}, 'phase_2': {0: 'REGARDING GRASS HOPPER IN PADDY', 1: 'CONTROL   OF GRASHOPPER   IN   PADDY    ', 2: 'COMTROL OF  GRASSHOPPER  IN    PADDY   ', 3: 'CONTROL FOR GRASSHOPPER IN RICE ', 4: 'REGARDING GRASSHOPPER ATTACK IN PADDY', 5: 'Farmer asked the query regarding grasshopper attack in paddy', 6: 'grasshopper in paddy crop', 7: 'regarding control of gross hopper ', 8: 'Farmer asked query regarding Attack of grasshopper in paddy', 9: 'Regarding control of grosshopper ', 10: nan, 11: nan, 12: nan}, 'phase_2_id': {0: '365_1', 1: '464_1', 2: '401_1', 3: '445_2', 4: '449_1', 5: '374_5', 6: '401_2', 7: '462_2', 8: '374_7', 9: '463_1', 10: nan, 11: nan, 12: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan, 9: nan, 10: nan, 11: nan, 12: nan}}
#
# 🔍 Evaluating Reference [172_1]: Regarding root weevil in paddy (Current Freq: 11)
#    Candidates remaining in pool: 98
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 6 potential IDs: ['438_1', '172_6', '172_5', '172_3', '445_3', '289_2']
#    [Pass 2] Verifying 6 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [172_6]: Information regarding the control of root weevil in paddy. (Freq: 1)
#       -> Matched [172_5]: How can I manage root weevils in paddy fields? (Freq: 1)
#    📈 Aggregating Frequencies: 11 + 2 = 13
#    🗑️  Removed 2 matches from the pool. New pool size: 96
# {'representative_question': {0: 'REGARDING ROOT WEEVIL IN PADDY', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'REGARDING RICE WEEVIL IN PADDY', 1: 'information regarding control root weevil in paddy', 2: 'ROOT WEEVIL IN PADDY', 3: 'Root Weevil in Transplanted rice ', 4: 'control of rice weaver', 5: 'RICE WEEVIL ATTACK IN NURSERY'}, 'phase_1_id': {0: '438_1', 1: '172_6', 2: '172_5', 3: '172_3', 4: '445_3', 5: '289_2'}, 'phase_2': {0: 'information regarding control root weevil in paddy', 1: 'ROOT WEEVIL IN PADDY', 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_2_id': {0: '172_6', 1: '172_5', 2: nan, 3: nan, 4: nan, 5: nan}, 'false_positive': {0: 'REGARDING ROOT WEEVIL IN PADDY', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}}
#
# 🔍 Evaluating Reference [419_1]: HOW TO CONTROL RAT IN PADDY (Current Freq: 11)
#    Candidates remaining in pool: 95
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['450_1', '445_4', '47_2', '27_8']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 4 verified matches.
#       -> Matched [450_1]: Regarding the rats attack in paddy (Freq: 3)
#       -> Matched [445_4]: How can I control rats in a paddy field? (Freq: 1)
#       -> Matched [47_2]: Regarding rodent management in paddy fields (Freq: 1)
#       -> Matched [27_8]: How can I manage rodents in a paddy field? (Freq: 1)
#    📈 Aggregating Frequencies: 11 + 6 = 17
#    🗑️  Removed 4 matches from the pool. New pool size: 91
# {'representative_question': {0: 'HOW TO CONTROL RAT IN PADDY ', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'Regarding the rats attack in paddy', 1: 'rat control in rice field', 2: 'REGARDING RODENT MANAGEMENT', 3: 'Regarding  Rodent Management in paddy field'}, 'phase_1_id': {0: '450_1', 1: '445_4', 2: '47_2', 3: '27_8'}, 'phase_2': {0: 'Regarding the rats attack in paddy', 1: 'rat control in rice field', 2: 'REGARDING RODENT MANAGEMENT', 3: 'Regarding  Rodent Management in paddy field'}, 'phase_2_id': {0: '450_1', 1: '445_4', 2: '47_2', 3: '27_8'}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [409_1]: CONTROL OF TERMITES IN PADDY (Current Freq: 10)
#    Candidates remaining in pool: 90
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['481_14']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [481_14]: Regarding the termites in paddy field (Freq: 1)
#    📈 Aggregating Frequencies: 10 + 1 = 11
#    🗑️  Removed 1 matches from the pool. New pool size: 89
# {'representative_question': {0: 'CONTROL  OF  TERMITE   IN  PADDY   '}, 'phase_1': {0: 'Regarding the termites in paddy field'}, 'phase_1_id': {0: '481_14'}, 'phase_2': {0: 'Regarding the termites in paddy field'}, 'phase_2_id': {0: '481_14'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [366_1]: Regarding hopper infestation in paddy field (Current Freq: 9)
#    Candidates remaining in pool: 88
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 7 potential IDs: ['335_2', '157_2', '345_1', '330_1', '481_4', '374_3', '477_2']
#    [Pass 2] Verifying 7 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [481_4]: Regarding hoppers in paddy (Freq: 1)
#    📈 Aggregating Frequencies: 9 + 1 = 10
#    🗑️  Removed 1 matches from the pool. New pool size: 87
# {'representative_question': {0: 'REGARDING HOPPER INFESTATION IN PADDY FIELD', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}, 'phase_1': {0: 'CONTROL OF GRASS HOPPER IN PADDY NURSERY ', 1: 'HOW TO CONTROL LEAF HOOPER IN PADDY ', 2: 'PROBLEM OF LEAF HOPPERS IN  PADDY ', 3: 'REGARDING THE LEAF HOPPER IN PADDY', 4: 'Farmer asked a query regarding grasshopper problem in an paddy crop', 5: 'REGARDING GRASSHOPPER PROBLEM IN THE RICE FIELD', 6: 'REGARDING HOPPERS IN PADDY '}, 'phase_1_id': {0: '335_2', 1: '157_2', 2: '345_1', 3: '330_1', 4: '374_3', 5: '477_2', 6: '481_4'}, 'phase_2': {0: 'REGARDING HOPPERS IN PADDY ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}, 'phase_2_id': {0: '481_4', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}, 'false_positive': {0: 'REGARDING HOPPER INFESTATION IN PADDY FIELD', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}}
#
# 🔍 Evaluating Reference [445_1]: How can I control rice hispa in paddy? (Current Freq: 9)
#    Candidates remaining in pool: 86
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['445_7', '446_2']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [445_7]: Regarding yellowing in paddy crop and rice hispa problem (Freq: 1)
#       -> Matched [446_2]: Rice hispa attack on paddy (Freq: 1)
#    📈 Aggregating Frequencies: 9 + 2 = 11
#    🗑️  Removed 2 matches from the pool. New pool size: 84
# {'representative_question': {0: 'CONTROL FROM RICE HISPA IN PADDY', 1: nan}, 'phase_1': {0: 'regarding yellowing in paddy crop and rice hispa problem ', 1: 'Rice hispa attack on paddy'}, 'phase_1_id': {0: '445_7', 1: '446_2'}, 'phase_2': {0: 'regarding yellowing in paddy crop and rice hispa problem ', 1: 'Rice hispa attack on paddy'}, 'phase_2_id': {0: '445_7', 1: '446_2'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [461_2]: Information regarding control of caterpillar in paddy (Current Freq: 7)
#    Candidates remaining in pool: 83
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['461_1']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [461_1]: How can I control caterpillars in my paddy field? (Freq: 3)
#    📈 Aggregating Frequencies: 7 + 3 = 10
#    🗑️  Removed 1 matches from the pool. New pool size: 82
# {'representative_question': {0: 'information regarding control of catterpillar in paddy'}, 'phase_1': {0: 'CONTROL OF CATERPILLAR'}, 'phase_1_id': {0: '461_1'}, 'phase_2': {0: 'CONTROL OF CATERPILLAR'}, 'phase_2_id': {0: '461_1'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [95_1]: What are the symptoms and control measures for stem borer attack in paddy? (Current Freq: 7)
#    Candidates remaining in pool: 81
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['118_7', '95_3']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [118_7]: What are the symptoms and management practices for yellow stem borer in paddy? (Freq: 5)
#    📈 Aggregating Frequencies: 7 + 5 = 12
#    🗑️  Removed 1 matches from the pool. New pool size: 80
# {'representative_question': {0: 'regarding stem borer attack in paddy', 1: nan}, 'phase_1': {0: 'regarding yellow stem borer in paddy', 1: 'REGARDING STEM BORER  ATTACK IN PADDY '}, 'phase_1_id': {0: '118_7', 1: '95_3'}, 'phase_2': {0: 'regarding yellow stem borer in paddy', 1: nan}, 'phase_2_id': {0: '118_7', 1: nan}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [120_1]: CONTROL OF CUT WORMS IN PADDY CROP (Current Freq: 7)
#    Candidates remaining in pool: 79
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 6 potential IDs: ['72_1', '79_1', '79_2', '120_3', '120_2', '481_10']
#    [Pass 2] Verifying 6 potential candidates...
#    ✅ SUCCESS: Found 5 verified matches.
#       -> Matched [72_1]: Regarding the attack of cut worms in paddy (Freq: 5)
#       -> Matched [79_1]: What is the best way to manage cutworms in paddy fields? (Freq: 4)
#       -> Matched [79_2]: Regarding cut worm control in paddy (Freq: 1)
#       -> Matched [120_3]: CONTROL OF CUT WORMS IN PADDY (Freq: 1)
#       -> Matched [481_10]: Regarding cutworm problem in paddy (Freq: 1)
#    📈 Aggregating Frequencies: 7 + 12 = 19
#    🗑️  Removed 5 matches from the pool. New pool size: 74
# {'representative_question': {0: 'CONTROL  OF   CUT  WORMS    IN  PADDY  CROP   ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'REGARDING ATTACK OF CUT WORMS IN PADDY ', 1: 'CUT WORM', 2: 'REGARDING CUT WORM CONTROL', 3: 'CONTROL OF  CUT   WORMS  IN   ', 4: 'Grubbs and cut worms control in paddy field', 5: 'Regarding cutworm problem in paddy'}, 'phase_1_id': {0: '72_1', 1: '79_1', 2: '79_2', 3: '120_3', 4: '120_2', 5: '481_10'}, 'phase_2': {0: 'REGARDING ATTACK OF CUT WORMS IN PADDY ', 1: 'CUT WORM', 2: 'REGARDING CUT WORM CONTROL', 3: 'CONTROL OF  CUT   WORMS  IN   ', 4: 'Regarding cutworm problem in paddy', 5: nan}, 'phase_2_id': {0: '72_1', 1: '79_1', 2: '79_2', 3: '120_3', 4: '481_10', 5: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}}
#
# 🔍 Evaluating Reference [435_2]: What are the common pests found in paddy nurseries and how can they be managed? (Current Freq: 7)
#    Candidates remaining in pool: 73
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['333_2']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [333_2]: How can I control insect infestations in the paddy nursery? (Freq: 1)
#    📈 Aggregating Frequencies: 7 + 1 = 8
#    🗑️  Removed 1 matches from the pool. New pool size: 72
# {'representative_question': {0: 'insects in paddy nursery'}, 'phase_1': {0: 'CONTROL FROM INSECT IN PADDY NURSERY'}, 'phase_1_id': {0: '333_2'}, 'phase_2': {0: 'CONTROL FROM INSECT IN PADDY NURSERY'}, 'phase_2_id': {0: '333_2'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [291_2]: Regarding the problem of reproductive growth issues in paddy, what could be the cause and how can it be managed? (Current Freq: 6)
#    Candidates remaining in pool: 71
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'insects in paddy nursery'}, 'phase_1': {0: 'CONTROL FROM INSECT IN PADDY NURSERY'}, 'phase_1_id': {0: '333_2'}, 'phase_2': {0: 'CONTROL FROM INSECT IN PADDY NURSERY'}, 'phase_2_id': {0: '333_2'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [335_2]: CONTROL OF GRASS HOPPER IN PADDY NURSERY (Current Freq: 6)
#    Candidates remaining in pool: 70
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['374_3', '477_2']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [374_3]: What are the common grasshopper problems in paddy crops and how can they be managed? (Freq: 3)
#       -> Matched [477_2]: Regarding grasshopper problem in the rice field (Freq: 1)
#    📈 Aggregating Frequencies: 6 + 4 = 10
#    🗑️  Removed 2 matches from the pool. New pool size: 68
# {'representative_question': {0: 'CONTROL OF GRASS HOPPER IN PADDY NURSERY ', 1: nan}, 'phase_1': {0: 'Farmer asked a query regarding grasshopper problem in an paddy crop', 1: 'REGARDING GRASSHOPPER PROBLEM IN THE RICE FIELD'}, 'phase_1_id': {0: '374_3', 1: '477_2'}, 'phase_2': {0: 'Farmer asked a query regarding grasshopper problem in an paddy crop', 1: 'REGARDING GRASSHOPPER PROBLEM IN THE RICE FIELD'}, 'phase_2_id': {0: '374_3', 1: '477_2'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [157_2]: HOW TO CONTROL LEAF HOOPER IN PADDY (Current Freq: 5)
#    Candidates remaining in pool: 67
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['330_1', '335_4']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [330_1]: Regarding the management of leaf hoppers in paddy (Freq: 4)
#    📈 Aggregating Frequencies: 5 + 4 = 9
#    🗑️  Removed 1 matches from the pool. New pool size: 66
# {'representative_question': {0: 'HOW TO CONTROL LEAF HOOPER IN PADDY ', 1: nan}, 'phase_1': {0: 'REGARDING THE LEAF HOPPER IN PADDY', 1: 'CONTROL OF PLANT  HOPPER  '}, 'phase_1_id': {0: '330_1', 1: '335_4'}, 'phase_2': {0: 'REGARDING THE LEAF HOPPER IN PADDY', 1: nan}, 'phase_2_id': {0: '330_1', 1: nan}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [345_1]: PROBLEM OF LEAF HOPPERS IN PADDY (Current Freq: 5)
#    Candidates remaining in pool: 65
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['335_4', '481_23']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [481_23]: What are the common symptoms and management practices for plant hoppers in paddy? (Freq: 1)
#       -> Matched [335_4]: How can I control the plant hopper in my paddy field? (Freq: 1)
#    📈 Aggregating Frequencies: 5 + 2 = 7
#    🗑️  Removed 2 matches from the pool. New pool size: 63
# {'representative_question': {0: 'PROBLEM OF LEAF HOPPERS IN  PADDY ', 1: nan}, 'phase_1': {0: 'regarding plant hoppers in paddy', 1: 'CONTROL OF PLANT  HOPPER  '}, 'phase_1_id': {0: '481_23', 1: '335_4'}, 'phase_2': {0: 'regarding plant hoppers in paddy', 1: 'CONTROL OF PLANT  HOPPER  '}, 'phase_2_id': {0: '481_23', 1: '335_4'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [135_2]: YELLOW STEM BORER IN PADDY (Current Freq: 5)
#    Candidates remaining in pool: 62
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['95_4', '95_3', '118_4', '118_3']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [95_4]: Information regarding yellowing of leaves in paddy and stem borer attack (Freq: 1)
#       -> Matched [95_3]: Regarding stem borer attack in paddy (Freq: 1)
#       -> Matched [118_3]: Regarding stem borer in paddy field, white dead hearts are seen. (Freq: 1)
#    📈 Aggregating Frequencies: 5 + 3 = 8
#    🗑️  Removed 3 matches from the pool. New pool size: 59
# {'representative_question': {0: 'YELLOW STEM BORER IN PADDY', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'info regarding yellowing of leaves in paddy  and stem borer attack', 1: 'REGARDING STEM BORER  ATTACK IN PADDY ', 2: 'Regarding stem borer management in transplanted paddy', 3: 'Regarding stem borer in paddy field White dead hearts are seen'}, 'phase_1_id': {0: '95_4', 1: '95_3', 2: '118_4', 3: '118_3'}, 'phase_2': {0: 'info regarding yellowing of leaves in paddy  and stem borer attack', 1: 'REGARDING STEM BORER  ATTACK IN PADDY ', 2: 'Regarding stem borer in paddy field White dead hearts are seen', 3: nan}, 'phase_2_id': {0: '95_4', 1: '95_3', 2: '118_3', 3: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [323_2]: What are the common pests that affect paddy and how can they be controlled? (Current Freq: 4)
#    Candidates remaining in pool: 58
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['423_1']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [423_1]: HOW TO CONTROL PADDY PESTS? (Freq: 3)
#    📈 Aggregating Frequencies: 4 + 3 = 7
#    🗑️  Removed 1 matches from the pool. New pool size: 57
# {'representative_question': {0: 'plant protection'}, 'phase_1': {0: 'HOW TO CONTROL'}, 'phase_1_id': {0: '423_1'}, 'phase_2': {0: 'HOW TO CONTROL'}, 'phase_2_id': {0: '423_1'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [316_3]: Regarding the application of mancozeb and dealing with insect attacks in paddy fields. (Current Freq: 3)
#    Candidates remaining in pool: 56
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'plant protection'}, 'phase_1': {0: 'HOW TO CONTROL'}, 'phase_1_id': {0: '423_1'}, 'phase_2': {0: 'HOW TO CONTROL'}, 'phase_2_id': {0: '423_1'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [449_2]: Regarding the attack of spikes in paddy bay sparrows (Current Freq: 3)
#    Candidates remaining in pool: 55
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'plant protection'}, 'phase_1': {0: 'HOW TO CONTROL'}, 'phase_1_id': {0: '423_1'}, 'phase_2': {0: 'HOW TO CONTROL'}, 'phase_2_id': {0: '423_1'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [72_2]: Regarding the attack of cut worms, leaf hoppers, and termites in the paddy field (Current Freq: 3)
#    Candidates remaining in pool: 54
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'plant protection'}, 'phase_1': {0: 'HOW TO CONTROL'}, 'phase_1_id': {0: '423_1'}, 'phase_2': {0: 'HOW TO CONTROL'}, 'phase_2_id': {0: '423_1'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [477_1]: What are the common weedicide problems in a paddy field and how can they be managed? (Current Freq: 3)
#    Candidates remaining in pool: 53
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['474_8', '474_4']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [474_8]: What are the common weed problems in paddy and how can they be managed? (Freq: 1)
#       -> Matched [474_4]: What are the common weeds in a rice field and how can they be controlled? (Freq: 1)
#    📈 Aggregating Frequencies: 3 + 2 = 5
#    🗑️  Removed 2 matches from the pool. New pool size: 51
# {'representative_question': {0: 'Query regarding weedicide problem in rice field', 1: nan}, 'phase_1': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_1_id': {0: '474_8', 1: '474_4'}, 'phase_2': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_2_id': {0: '474_8', 1: '474_4'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [202_1]: Information regarding control of Brown Plant hopper, Leaf folder, Whorl Maggot, Gall midge, and Green leaf hopper in paddy. (Current Freq: 3)
#    Candidates remaining in pool: 50
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Query regarding weedicide problem in rice field', 1: nan}, 'phase_1': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_1_id': {0: '474_8', 1: '474_4'}, 'phase_2': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_2_id': {0: '474_8', 1: '474_4'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [147_2]: What are the common issues related to frogs and algal growth in paddy fields, and how can they be managed? (Current Freq: 3)
#    Candidates remaining in pool: 49
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Query regarding weedicide problem in rice field', 1: nan}, 'phase_1': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_1_id': {0: '474_8', 1: '474_4'}, 'phase_2': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_2_id': {0: '474_8', 1: '474_4'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [373_2]: How should carbofuran be applied in a paddy field to control pests effectively? (Current Freq: 2)
#    Candidates remaining in pool: 48
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Query regarding weedicide problem in rice field', 1: nan}, 'phase_1': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_1_id': {0: '474_8', 1: '474_4'}, 'phase_2': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_2_id': {0: '474_8', 1: '474_4'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [438_1]: Regarding Rice Weevil in Paddy (Current Freq: 2)
#    Candidates remaining in pool: 47
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> [WARNING] JSON decoding failed in Pass 1 for a batch.
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Query regarding weedicide problem in rice field', 1: nan}, 'phase_1': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_1_id': {0: '474_8', 1: '474_4'}, 'phase_2': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_2_id': {0: '474_8', 1: '474_4'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [385_9]: Regarding the burning of leaves in a paddy nursery (Current Freq: 2)
#    Candidates remaining in pool: 46
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Query regarding weedicide problem in rice field', 1: nan}, 'phase_1': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_1_id': {0: '474_8', 1: '474_4'}, 'phase_2': {0: 'weed problem in rice', 1: 'WEED IN RICE FIELD'}, 'phase_2_id': {0: '474_8', 1: '474_4'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [464_4]: How can I control alage in a paddy field? (Current Freq: 2)
#    Candidates remaining in pool: 45
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['273_12']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [273_12]: CONTROL OF GREEN ALGAE IN PADDY NURSERY (Freq: 1)
#    📈 Aggregating Frequencies: 2 + 1 = 3
#    🗑️  Removed 1 matches from the pool. New pool size: 44
# {'representative_question': {0: 'CONTROL OF ALAGE IN PADDY FIELD '}, 'phase_1': {0: 'CONTROL  OF    GREEN  ALGE  IN  PADDY  NURSERY   '}, 'phase_1_id': {0: '273_12'}, 'phase_2': {0: 'CONTROL  OF    GREEN  ALGE  IN  PADDY  NURSERY   '}, 'phase_2_id': {0: '273_12'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [269_2]: HOW TO CONTROL STORAGE PESTS IN STORED RICE (Current Freq: 2)
#    Candidates remaining in pool: 43
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['271_8', '440_1', '289_3']
#    [Pass 2] Verifying 3 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'CONTROL OF ALAGE IN PADDY FIELD '}, 'phase_1': {0: 'CONTROL  OF    GREEN  ALGE  IN  PADDY  NURSERY   '}, 'phase_1_id': {0: '273_12'}, 'phase_2': {0: 'CONTROL  OF    GREEN  ALGE  IN  PADDY  NURSERY   '}, 'phase_2_id': {0: '273_12'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [119_3]: How can I control the effects of 2,4-D on my paddy field? (Current Freq: 2)
#    Candidates remaining in pool: 42
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'CONTROL OF ALAGE IN PADDY FIELD '}, 'phase_1': {0: 'CONTROL  OF    GREEN  ALGE  IN  PADDY  NURSERY   '}, 'phase_1_id': {0: '273_12'}, 'phase_2': {0: 'CONTROL  OF    GREEN  ALGE  IN  PADDY  NURSERY   '}, 'phase_2_id': {0: '273_12'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [271_8]: What are the common storage pests that attack paddy and how can they be managed? (Current Freq: 2)
#    Candidates remaining in pool: 41
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['440_1', '289_3']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [440_1]: How can I prevent paddy from pests during storage after harvest? (Freq: 2)
#    📈 Aggregating Frequencies: 2 + 2 = 4
#    🗑️  Removed 1 matches from the pool. New pool size: 40
# {'representative_question': {0: 'regarding attack of storage pest in paddy', 1: nan}, 'phase_1': {0: 'Farmer ask the query regarding prevention of paddy after harvest storage pest', 1: 'RICE STORAGE IN BINS WWT AND INSECT ATTACK'}, 'phase_1_id': {0: '440_1', 1: '289_3'}, 'phase_2': {0: 'Farmer ask the query regarding prevention of paddy after harvest storage pest', 1: nan}, 'phase_2_id': {0: '440_1', 1: nan}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [228_2]: Wilting of plants in the field (Current Freq: 2)
#    Candidates remaining in pool: 39
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['422_3']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'regarding attack of storage pest in paddy', 1: nan}, 'phase_1': {0: 'Farmer ask the query regarding prevention of paddy after harvest storage pest', 1: 'RICE STORAGE IN BINS WWT AND INSECT ATTACK'}, 'phase_1_id': {0: '440_1', 1: '289_3'}, 'phase_2': {0: 'Farmer ask the query regarding prevention of paddy after harvest storage pest', 1: nan}, 'phase_2_id': {0: '440_1', 1: nan}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [53_2]: What are the common issues with thread worms in paddy variety 1121 and how can they be managed? (Current Freq: 2)
#    Candidates remaining in pool: 38
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['65_2']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [65_2]: What is the treatment for threadworm in paddy? (Freq: 1)
#    📈 Aggregating Frequencies: 2 + 1 = 3
#    🗑️  Removed 1 matches from the pool. New pool size: 37
# {'representative_question': {0: 'problem of thread worms in paddy  variety- 1121 '}, 'phase_1': {0: 'thread worm in paddy '}, 'phase_1_id': {0: '65_2'}, 'phase_2': {0: 'thread worm in paddy '}, 'phase_2_id': {0: '65_2'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [451_1]: Regarding the attack of aphids on paddy (Current Freq: 2)
#    Candidates remaining in pool: 36
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'problem of thread worms in paddy  variety- 1121 '}, 'phase_1': {0: 'thread worm in paddy '}, 'phase_1_id': {0: '65_2'}, 'phase_2': {0: 'thread worm in paddy '}, 'phase_2_id': {0: '65_2'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [285_2]: How can I control paddy plants with burned leaves? (Current Freq: 2)
#    Candidates remaining in pool: 35
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'problem of thread worms in paddy  variety- 1121 '}, 'phase_1': {0: 'thread worm in paddy '}, 'phase_1_id': {0: '65_2'}, 'phase_2': {0: 'thread worm in paddy '}, 'phase_2_id': {0: '65_2'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [130_2]: Regarding the attack of cutworms and subsequent yellowing of paddy. (Current Freq: 2)
#    Candidates remaining in pool: 34
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'problem of thread worms in paddy  variety- 1121 '}, 'phase_1': {0: 'thread worm in paddy '}, 'phase_1_id': {0: '65_2'}, 'phase_2': {0: 'thread worm in paddy '}, 'phase_2_id': {0: '65_2'}, 'false_positive': {0: nan}}
#
# ...
#
# 🔍 Evaluating Reference [47_1]: REGARDING NUTRIENT MANAGEMENT IN MAIZE (Current Freq: 2)
#    Candidates remaining in pool: 18
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'CONTROL  OF  WEEDS  CONTROL IN  WHEA', 1: nan}, 'phase_1': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_1_id': {0: '50_1', 1: '50_2'}, 'phase_2': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_2_id': {0: '50_1', 1: '50_2'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [210_2]: HOW TO CONTROL DOWNY MILDEW IN ONION CROP (Current Freq: 1)
#    Candidates remaining in pool: 17
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'CONTROL  OF  WEEDS  CONTROL IN  WHEA', 1: nan}, 'phase_1': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_1_id': {0: '50_1', 1: '50_2'}, 'phase_2': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_2_id': {0: '50_1', 1: '50_2'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [111_1]: HOW TO CONTROL WEEDS IN APPLE TREES (Current Freq: 1)
#    Candidates remaining in pool: 16
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'CONTROL  OF  WEEDS  CONTROL IN  WHEA', 1: nan}, 'phase_1': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_1_id': {0: '50_1', 1: '50_2'}, 'phase_2': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_2_id': {0: '50_1', 1: '50_2'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [111_2]: CONTROL OF SANJOSCALE IN APPLE TREES (Current Freq: 1)
#    Candidates remaining in pool: 15
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'CONTROL  OF  WEEDS  CONTROL IN  WHEA', 1: nan}, 'phase_1': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_1_id': {0: '50_1', 1: '50_2'}, 'phase_2': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_2_id': {0: '50_1', 1: '50_2'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [111_3]: HOW TO CONTROL ALTERNARIA LEAF BLIGHT IN APPLE TREES (Current Freq: 1)
#    Candidates remaining in pool: 14
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'CONTROL  OF  WEEDS  CONTROL IN  WHEA', 1: nan}, 'phase_1': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_1_id': {0: '50_1', 1: '50_2'}, 'phase_2': {0: 'CONTROL FROM WEEDS IN WHEAT', 1: 'CONTROL OF WEEDS IN   WHEAT CROP  '}, 'phase_2_id': {0: '50_1', 1: '50_2'}, 'false_positive': {0: nan, 1: nan}}
#
# 🔍 Evaluating Reference [111_4]: HOW TO CONTROL FLOWER DROP IN APPLE TREES (Current Freq: 1)
#    Candidates remaining in pool: 13
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['111_11']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [111_11]: INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE (Freq: 1)
#    📈 Aggregating Frequencies: 1 + 1 = 2
#    🗑️  Removed 1 matches from the pool. New pool size: 12
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [111_5]: HOW TO CONTROL INSECT IN APPLE (Current Freq: 1)
#    Candidates remaining in pool: 11
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [111_6]: HOW TO CONTROL RATS IN APPLE ORCHARD (Current Freq: 1)
#    Candidates remaining in pool: 10
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [111_12]: How can I control mites in apple trees? (Current Freq: 1)
#    Candidates remaining in pool: 9
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [111_9]: HOW TO CONTROL WOOLY APHIDS IN APPLE TREES (Current Freq: 1)
#    Candidates remaining in pool: 8
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [351_9]: Regarding fruit fly problem in bottle gourd Cucurbit fruit fly (Current Freq: 1)
#    Candidates remaining in pool: 7
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [111_7]: HOW TO CONTROL SCAB IN APPLE (Current Freq: 1)
#    Candidates remaining in pool: 6
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [462_1]: INFORMATION REGARDING THE CONTROL OF APHIDS IN CAULIFLOWERPHULGOBHI CROP (Current Freq: 1)
#    Candidates remaining in pool: 5
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [61_2]: DOSE OF COPPER OXYCHLORIDE IN APPLE TREES (Current Freq: 1)
#    Candidates remaining in pool: 4
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [103_3]: SPRAY AT FRUIT DEVT STAGE 2 IN APPLE (Current Freq: 1)
#    Candidates remaining in pool: 3
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [103_6]: What is the correct procedure for spraying apple trees? (Current Freq: 1)
#    Candidates remaining in pool: 2
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [92_2]: SPRAY FOR DIE BACK IN CHILLY (Current Freq: 1)
#    Candidates remaining in pool: 1
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# [INFO] Only 1 row left in category. Saving Reference [17_2] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Fungicide and Nutrient
# ======================================================================
# [INFO] Total rows to process in 'Fungicide and Nutrient': 1
#
# [INFO] Only 1 row left in category. Saving Reference [154_1] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Other
# ======================================================================
# [INFO] Total rows to process in 'Other': 8
#
# 🔍 Evaluating Reference [49_2]: How can I control Congress grass in my paddy field? (Current Freq: 3)
#    Candidates remaining in pool: 7
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [178_1]: How can I subscribe to the SMS service for paddy farming updates? (Current Freq: 3)
#    Candidates remaining in pool: 6
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [351_2]: INFORMATION REGARDING FINANCE FOR TUBE WELL (Current Freq: 2)
#    Candidates remaining in pool: 5
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [386_15]: Regarding the addition of sugar in paddy nursery, is it beneficial for the growth of the seedlings? (Current Freq: 1)
#    Candidates remaining in pool: 4
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [351_4]: INFORMATION REGARDING THE FAODDER SHORTAGE (Current Freq: 1)
#    Candidates remaining in pool: 3
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [393_2]: Regarding the smell coming out of paddy seed as it is soaked for 4 days? (Current Freq: 1)
#    Candidates remaining in pool: 2
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# 🔍 Evaluating Reference [300_2]: Sunshine mixing with some clouds with a thunderstorm in spots this afternoon (Current Freq: 1)
#    Candidates remaining in pool: 1
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'HOW TO CONTROL FLOWER DROP IN APPLE TREES '}, 'phase_1': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_1_id': {0: '111_11'}, 'phase_2': {0: 'INFORMATION REGARDING THE CONTROL OF FLOWER DROP IN APPLE'}, 'phase_2_id': {0: '111_11'}, 'false_positive': {0: nan}}
#
# [INFO] Only 1 row left in category. Saving Reference [481_20] directly.
#
# ======================================================================
# 🎉 PROCESSING COMPLETE
# ======================================================================
# Original Dataset Size: 936
# Cleaned Dataset Size: 343
# Saved phase output: phase_data_paddy_faq.csv
# Saved final output: dedup_paddy_faq.csv

# %%
import pandas as pd            
import numpy as np
                                                                                                                                        
ref_phase = pd.DataFrame({
      'representative_question': ['HOW TO CONTROL THREAD WORMS IN PADDY FIELD', np.nan, np.nan, np.nan, np.nan, np.nan],                
      'phase_1': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Thread worm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 'Threadworms in paddy', 'infomation regarding threadworm in paddy', 'thread worm in paddy'],  
      'phase_1_id': ['39_1', '65_1', '66_1', '486_1', '482_11', '65_2'],                                                                
      'phase_2': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Thread worm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 'Threadworms in paddy', 'infomation regarding threadworm in paddy', np.nan],                  
      'phase_2_id': ['39_1', '65_1', '66_1', '486_1', '482_11', np.nan],                                                                
  })   

phase_2_ids = set(ref_phase['phase_2_id'].dropna())                                                                                   
removed_mask = ~ref_phase['phase_1_id'].isin(phase_2_ids)                                                                             
ref_phase['false_positive'] = ref_phase.loc[removed_mask, 'phase_1']
false_positives = ref_phase['false_positive'].dropna().reset_index(drop=True)                                                         
ref_phase['false_positive'] = false_positives 

ref_phase
# Out:
#                       representative_question  \
# 0  HOW TO CONTROL THREAD WORMS IN PADDY FIELD
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
#
#                                              phase_1 phase_1_id  \
# 0                    CONTROL OF THREADWORMS IN PADDY       39_1
# 1  Farmer asked a query regarding Thread worm pro...       65_1
# 2  REGARDING THE ATTACK OF THREAD WORMS IN PADDY ...       66_1
# 3                               Threadworms in paddy      486_1
# 4           infomation regarding threadworm in paddy     482_11
# 5                               thread worm in paddy       65_2
#
#                                              phase_2 phase_2_id  \
# 0                    CONTROL OF THREADWORMS IN PADDY       39_1
# 1  Farmer asked a query regarding Thread worm pro...       65_1
# 2  REGARDING THE ATTACK OF THREAD WORMS IN PADDY ...       66_1
# 3                               Threadworms in paddy      486_1
# 4           infomation regarding threadworm in paddy     482_11
# 5                                                NaN        NaN
#
#          false_positive
# 0  thread worm in paddy
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
