# %%
import requests

def gemma_4_26b_it_completion(prompt, max_tokens=512, temperature=0.0, top_p=0.95, stop=None):
    """
    Wrapper function to call the google/gemma-3-12b-it model, exposed via OpenAI-style API.

    Args:
        prompt (str): The prompt to send to the model.
        max_tokens (int): The maximum number of tokens to generate.
        temperature (float): Sampling temperature.
        top_p (float): Nucleus sampling probability.
        stop (list or str, optional): Stop sequence(s).

    Returns:
        str: The model's generated text completion.
    """
    api_url = "http://100.100.108.44:8013/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    data = {
        "model": "google/gemma-4-26B-A4B-it",
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": max_tokens,
        "temperature": temperature,
        "top_p": top_p,
    }
    if stop is not None:
        data["stop"] = stop

    response = requests.post(api_url, headers=headers, json=data)
    if response.status_code == 200:
        completion = response.json()
        return completion['choices'][0]['message']['content']
    else:
        raise RuntimeError(f"Failed to fetch completion: {response.status_code} - {response.text}")

# %%
import pandas as pd
import re
import json
from tqdm.auto import tqdm

def deduplicate_and_aggregate(df, text_col='Generated_Question', batch_size=100):
    """
    Iterates through categories, finds similar questions using LLM, 
    aggregates 'raw_frequency', and removes duplicates with full logging.
    """
    # Ensure raw_frequency is numeric to allow summing
    df['raw_frequency'] = pd.to_numeric(df['raw_frequency'], errors='coerce').fillna(0)

    phase_data = []
    final_cleaned_data = []
    categories = df['Generated_Category'].unique()

    # Outer progress bar for categories
    category_pbar = tqdm(categories, desc="Processing Categories", position=0)

    for category in category_pbar:
        # Update progress bar postfix to show current category
        category_pbar.set_postfix({"Current": category})
        
        tqdm.write(f"\n{'='*70}")
        tqdm.write(f"🚀 STARTING CATEGORY: {category}")
        tqdm.write(f"{'='*70}")
        
        # Isolate rows for the current category
        cat_df = df[df['Generated_Category'] == category].copy()
        total_initial = len(cat_df)
        tqdm.write(f"[INFO] Total rows to process in '{category}': {total_initial}")
        
        # Loop until no rows are left in this category's pool
        while not cat_df.empty:
            # Pop the first row to act as the reference
            ref_phase = []
            reference_row = cat_df.iloc[0].copy()
            ref_phase.append({                                                                     
                      'representative_question': reference_row['representative_question']
                  })
            ref_id = reference_row['unique_q_id']
            ref_question = reference_row[text_col]
            current_freq = reference_row['raw_frequency']
            
            # The candidates are all OTHER rows in this category
            remaining_df = cat_df.iloc[1:].reset_index(drop=True)
            
            if remaining_df.empty:
                tqdm.write(f"\n[INFO] Only 1 row left in category. Saving Reference [{ref_id}] directly.")
                final_cleaned_data.append(reference_row.to_dict())
                break
                
            tqdm.write(f"\n🔍 Evaluating Reference [{ref_id}]: {ref_question} (Current Freq: {current_freq})")
            tqdm.write(f"   Candidates remaining in pool: {len(remaining_df)}")
            
            # Find matches using the 2-pass LLM approach
            matched_ids, ref_phase = _get_verified_matches(reference_row, remaining_df, text_col, batch_size, ref_phase)
            
            if matched_ids:
                # Isolate the matched rows
                matches_df = remaining_df[remaining_df['unique_q_id'].isin(matched_ids)]

                ## Adding info to ref_phase
                ref_phase = pd.concat([                                                                            
                            ref_phase,
                            matches_df[['representative_question', 'unique_q_id']].rename(columns={                 
                                    'representative_question': 'phase_2',                                      
                                    'unique_q_id': 'phase_2_id'
                            }).reset_index(drop=True)                                                          
                            ], axis=1)

                
                phase_2_ids = set(ref_phase['phase_2_id'].dropna())   
                removed_mask = ~ref_phase['phase_1_id'].isin(phase_2_ids)
                ref_phase['false_positive'] = ref_phase.loc[removed_mask, 'phase_1']                   
                false_positives = ref_phase['false_positive'].dropna()
                ref_phase['false_positive'] = false_positives                                          
                ref_phase.drop(columns=['phase_1_id', 'phase_2_id'], inplace=True)                     
                ref_phase = ref_phase[['representative_question', 'phase_1', 'false_positive','phase_2']]                                                                                
                ref_phase = pd.concat([ref_phase, pd.DataFrame([{}])], ignore_index=True)

                phase_data.append(ref_phase)
                
                # Sum the raw_frequency of the matches
                summed_frequency = matches_df['raw_frequency'].sum()
    
                tqdm.write(f"   ✅ SUCCESS: Found {len(matched_ids)} verified matches.")
                for _, m_row in matches_df.iterrows():
                    tqdm.write(f"      -> Matched [{m_row['unique_q_id']}]: {m_row[text_col]} (Freq: {m_row['raw_frequency']})")
                    
                tqdm.write(f"   📈 Aggregating Frequencies: {current_freq} + {summed_frequency} = {current_freq + summed_frequency}")
                    
                # Add it to the reference row
                reference_row['raw_frequency'] += summed_frequency
                    
                # Remove matched rows from the remaining pool
                cat_df = remaining_df[~remaining_df['unique_q_id'].isin(matched_ids)].reset_index(drop=True)
                tqdm.write(f"   🗑️  Removed {len(matched_ids)} matches from the pool. New pool size: {len(cat_df)}")
                
            else:
                tqdm.write("   ❌ No matches found. Moving to next row.")
                # No matches, so the next pool is just the remaining items
                cat_df = remaining_df
                    
                # Save the updated reference row to our final list
                final_cleaned_data.append(reference_row.to_dict())

            print(phase_data[-1].to_dict())

    tqdm.write(f"\n{'='*70}\n🎉 PROCESSING COMPLETE\n{'='*70}")
    tqdm.write(f"Original Dataset Size: {len(df)}")
    tqdm.write(f"Cleaned Dataset Size: {len(final_cleaned_data)}")
    
    # Return the clean, aggregated DataFrame
    return pd.DataFrame(final_cleaned_data), pd.concat(phase_data, ignore_index=True)


def _get_verified_matches(reference_row, candidate_df, text_col, batch_size, ref_phase):
    """
    Helper function running the 2-pass LLM matching logic with batch-level progress and logging.
    """
    original_id = reference_row['unique_q_id']
    original_question = reference_row[text_col]
    
    all_candidate_ids = []
    
    # Calculate total batches for tqdm
    total_batches = (len(candidate_df) + batch_size - 1) // batch_size

    # --- PASS 1: Batch Initial Search ---
    tqdm.write("   [Pass 1] Scanning for initial candidates...")
    
    # Inner progress bar for batches (leave=False hides it after it finishes)
    for start in tqdm(range(0, len(candidate_df), batch_size), total=total_batches, desc="Pass 1 Batches", leave=False):
        batch = candidate_df.iloc[start:start+batch_size]

        batch_text = "\n".join([
            f"{row['unique_q_id']}: {row[text_col]}"
            for _, row in batch.iterrows()
        ])

        prompt = f"""
You are given one reference question and a list of candidate questions.
Task: Return ONLY the IDs of questions that exact same or rephrased to the reference question.
Rules:
- Output ONLY a JSON list of matching IDs
- No explanation
- If none match, return []

Reference:
{original_id}: {original_question}

Candidates:
{batch_text}

Output:
"""
        # Call your LLM here
        response = gemma_4_26b_it_completion(prompt, max_tokens=2000, temperature=0.0)

        match = re.search(r'\[.*\]', response, re.DOTALL)
        if match:
            try:
                found_in_batch = json.loads(match.group(0))
                if found_in_batch:
                    tqdm.write(f"      -> Batch flagged {len(found_in_batch)} potential IDs: {found_in_batch}")
                all_candidate_ids.extend(found_in_batch)
            except json.JSONDecodeError:
                tqdm.write("      -> [WARNING] JSON decoding failed in Pass 1 for a batch.")

    ref_phase = pd.DataFrame(ref_phase)
    
    # --- PASS 2: Verification ---
    if not all_candidate_ids:
        return [], ref_phase
    
    tqdm.write(f"   [Pass 2] Verifying {len(all_candidate_ids)} potential candidates...")
    candidate_rows = candidate_df[candidate_df['unique_q_id'].isin(all_candidate_ids)]

    #adding info to ref_phase
    ref_phase = pd.concat([                                                                            
                ref_phase,
                candidate_rows[['representative_question', 'unique_q_id']].rename(columns={                 
                                        'representative_question': 'phase_1',                                      
                                        'unique_q_id': 'phase_1_id'
                                }).reset_index(drop=True)                                                          
                                ], axis=1)
    
    verification_batch_text = "\n".join([
        f"{row['unique_q_id']}: {row[text_col]}"
        for _, row in candidate_rows.iterrows()
    ])

    verification_prompt = f"""
Task: Strictly review these candidates. Remove any questions that are NOT the exact same or a direct rephrase.
Rules: Output ONLY a JSON list of matching IDs. No explanation. If none match, return [].

Reference:
{original_id}: {original_question}

Candidates to Verify:
{verification_batch_text}

Output:
"""
    verification_response = gemma_4_26b_it_completion(verification_prompt, max_tokens=2000, temperature=0.0)

    final_matched_ids = []
    final_match = re.search(r'\[.*\]', verification_response, re.DOTALL)
    if final_match:
        try:
            final_matched_ids = json.loads(final_match.group(0))
        except json.JSONDecodeError:
            tqdm.write("      -> [WARNING] JSON decoding failed in Pass 2.")

    # Filter out any hallucinated IDs that weren't actually in the candidates pool
    final_matched_ids = [mid for mid in final_matched_ids if mid in all_candidate_ids]

    return final_matched_ids, ref_phase

# %%
from pathlib import Path
import pandas as pd

crops_folder = Path('../outputs/repair/final')


for csv_file in crops_folder.glob("*.csv"):
    print(f"Processing: {csv_file.name}")

    output_name_phase = f"phase_data_{csv_file.name}"
    output_name_final = f"dedup_{csv_file.name}"
    
    output_path_phase = crops_folder / output_name_phase
    output_path_final = crops_folder / output_name_final
    
    try:
        # Read CSV
        df = pd.read_csv(csv_file, low_memory=False)

        # Risky step
        df, df1 = deduplicate_and_aggregate(df)

    except Exception as e:
        print(f"[ERROR] Failed processing {csv_file.name}: {e}")
        continue  # skip this file and move to next

    # Save intermediate
    df1.to_csv(output_path_phase, index=False)

    # Filter
    df = df[df['answer_label'] != "(unclassified)"]

    # Save final
    df.to_csv(output_path_final, index=False)

    print(f"Saved phase output: {output_name_phase}")
    print(f"Saved final output: {output_name_final}")
# Out:
# Processing: watermelon_faq.csv
# Processing Categories:   0%|          | 0/11 [00:00<?, ?it/s]
# ======================================================================
# 🚀 STARTING CATEGORY: Agronomy
# ======================================================================
# [INFO] Total rows to process in 'Agronomy': 192
#
# 🔍 Evaluating Reference [461_1]: What is the best time to sow watermelon seeds? (Current Freq: 1733)
#    Candidates remaining in pool: 191
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 5 potential IDs: ['394_1', '315_1', '385_2', '155_4', '427_1']
#       -> Batch flagged 6 potential IDs: ['393_4', '318_2', '153_4', '152_3', '542_2', '153_3']
#    [Pass 2] Verifying 11 potential candidates...
#    ✅ SUCCESS: Found 5 verified matches.
#       -> Matched [394_1]: What is the ideal sowing season for watermelon? (Freq: 13)
#       -> Matched [315_1]: What is the ideal sowing season for watermelon? (Freq: 6)
#       -> Matched [385_2]: What is the suitable sowing season for watermelon? (Freq: 3)
#       -> Matched [152_3]: When is the best time to sow watermelon seeds? (Freq: 1)
#       -> Matched [542_2]: What is the best time to sow watermelon seeds? (Freq: 1)
#    📈 Aggregating Frequencies: 1733 + 24 = 1757
#    🗑️  Removed 5 matches from the pool. New pool size: 186
# {'representative_question': {0: 'asking about watermelon sowing season', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan, 9: nan, 10: nan, 11: nan}, 'phase_1': {0: 'Asking about Musk melon sowing season ', 1: 'water melon sowing season details', 2: 'Asking about Sowing season of Vegetable crops', 3: 'Asked about Suitable seasons for Crops ', 4: 'suitable sowing season for watermilon', 5: 'Asking about Water melon sowing season and seed availability ', 6: 'Watermelon season : Sow the seeds during November  December', 7: 'planting season for watermelin', 8: 'Muskmelon sowing', 9: 'Asking about sowing time for watermelon', 10: 'watermelon planting time for seedling', 11: nan}, 'false_positive': {0: nan, 1: 'water melon sowing season details', 2: nan, 3: 'Asked about Suitable seasons for Crops ', 4: nan, 5: 'Asking about Water melon sowing season and seed availability ', 6: 'Watermelon season : Sow the seeds during November  December', 7: 'planting season for watermelin', 8: nan, 9: nan, 10: 'watermelon planting time for seedling', 11: nan}, 'phase_2': {0: 'Asking about Musk melon sowing season ', 1: 'Asking about Sowing season of Vegetable crops', 2: 'suitable sowing season for watermilon', 3: 'Muskmelon sowing', 4: 'Asking about sowing time for watermelon', 5: nan, 6: nan, 7: nan, 8: nan, 9: nan, 10: nan, 11: nan}}
#
# 🔍 Evaluating Reference [345_2]: What is the best time and method for applying foliar spray in watermelon? (Current Freq: 552)
#    Candidates remaining in pool: 185
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['475_1', '602_1', '370_2', '400_1']
#       -> Batch flagged 2 potential IDs: ['372_3', '54_2']
#    [Pass 2] Verifying 6 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [372_3]: What is the best time and method for applying foliar spray in watermelon? (Freq: 1)
#       -> Matched [54_2]: What is the correct method for applying foliar sprays to watermelons and when should these sprays be applied? (Freq: 1)
#    📈 Aggregating Frequencies: 552 + 2 = 554
#    🗑️  Removed 2 matches from the pool. New pool size: 183
# {'representative_question': {0: 'Asking about foliar spray in watermelon', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}, 'phase_1': {0: 'Asking about watermelon foliar application information', 1: 'foliar application for water melon', 2: 'water melon foliar spray details', 3: 'Asking about  foliar application details', 4: 'asking about foliar spray in musk melon', 5: 'Asking about Watermelon Foliar spray application and spray timings ', 6: nan}, 'false_positive': {0: 'Asking about watermelon foliar application information', 1: 'foliar application for water melon', 2: 'water melon foliar spray details', 3: 'Asking about  foliar application details', 4: nan, 5: nan, 6: nan}, 'phase_2': {0: 'asking about foliar spray in musk melon', 1: 'Asking about Watermelon Foliar spray application and spray timings ', 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}}
#
# 🔍 Evaluating Reference [318_1]: What is the watermelon season? (Current Freq: 363)
#    Candidates remaining in pool: 182
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['427_1']
#       -> Batch flagged 7 potential IDs: ['318_2', '153_4', '153_3', '393_4', '355_6', '0_2', '393_6']
#    [Pass 2] Verifying 8 potential candidates...
#    ✅ SUCCESS: Found 4 verified matches.
#       -> Matched [427_1]: What are the suitable seasons for growing watermelons? (Freq: 3)
#       -> Matched [318_2]: Watermelon season: When should I sow the seeds? (Freq: 1)
#       -> Matched [153_4]: What is the best planting season for watermelon? (Freq: 1)
#       -> Matched [153_3]: What is the optimal planting time for watermelon seedlings? (Freq: 1)
#    📈 Aggregating Frequencies: 363 + 6 = 369
#    🗑️  Removed 4 matches from the pool. New pool size: 178
# {'representative_question': {0: 'watermelon season', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan}, 'phase_1': {0: 'Asked about Suitable seasons for Crops ', 1: 'water melon season and ph range', 2: 'Asking about Water melon sowing season and seed availability ', 3: 'Asked about Watermelon suitable spacing and season', 4: 'Asking about sowing season  seed rate  transplanting age for water melon', 5: 'Watermelon season : Sow the seeds during November  December', 6: 'planting season for watermelin', 7: 'watermelon planting time for seedling', 8: nan}, 'false_positive': {0: nan, 1: 'water melon season and ph range', 2: 'Asking about Water melon sowing season and seed availability ', 3: 'Asked about Watermelon suitable spacing and season', 4: 'Asking about sowing season  seed rate  transplanting age for water melon', 5: nan, 6: nan, 7: nan, 8: nan}, 'phase_2': {0: 'Asked about Suitable seasons for Crops ', 1: 'Watermelon season : Sow the seeds during November  December', 2: 'planting season for watermelin', 3: 'watermelon planting time for seedling', 4: nan, 5: nan, 6: nan, 7: nan, 8: nan}}
#
# 🔍 Evaluating Reference [493_1]: Flower drop in watermelon (Current Freq: 218)
#    Candidates remaining in pool: 177
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['523_1', '493_3', '267_1']
#       -> Batch flagged 2 potential IDs: ['456_9', '20_4']
#    [Pass 2] Verifying 5 potential candidates...
#    ✅ SUCCESS: Found 5 verified matches.
#       -> Matched [523_1]: What are the management practices for flower drop and premature fruit drop in watermelon? (Freq: 28)
#       -> Matched [493_3]: Flower shed in watermelon (Freq: 6)
#       -> Matched [267_1]: What are the control measures for flower drop in watermelons? (Freq: 3)
#       -> Matched [456_9]: My watermelon plants are experiencing premature fruit dropping. What could be the cause and how can I prevent it? (Freq: 1)
#       -> Matched [20_4]: Asked about foliar spray application for flower shedding management in watermelon (Freq: 1)
#    📈 Aggregating Frequencies: 218 + 39 = 257
#    🗑️  Removed 5 matches from the pool. New pool size: 172
# {'representative_question': {0: 'Flower drop in watermelon', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'Asked about flowerd drop and premature fruit drop management in watermelon', 1: 'flower shed in watermelon', 2: 'control measure for flower drop', 3: 'asking about watermelon premature fruit dropping', 4: 'Asked about foliar spray application for flower shedding mangement in watermelon\t', 5: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_2': {0: 'Asked about flowerd drop and premature fruit drop management in watermelon', 1: 'flower shed in watermelon', 2: 'control measure for flower drop', 3: 'asking about watermelon premature fruit dropping', 4: 'Asked about foliar spray application for flower shedding mangement in watermelon\t', 5: nan}}
#
# 🔍 Evaluating Reference [386_1]: Watermelon foliar application details (Current Freq: 211)
#    Candidates remaining in pool: 171
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 5 potential IDs: ['475_1', '602_1', '370_2', '400_1', '372_1']
#    [Pass 2] Verifying 5 potential candidates...
#    ✅ SUCCESS: Found 5 verified matches.
#       -> Matched [475_1]: What is the correct method for foliar application in watermelon cultivation? (Freq: 136)
#       -> Matched [602_1]: What is the foliar application method for watermelon? (Freq: 14)
#       -> Matched [370_2]: Watermelon foliar spray details (Freq: 14)
#       -> Matched [400_1]: What are the details for foliar application in watermelon cultivation? (Freq: 5)
#       -> Matched [372_1]: Asked about foliar spray in watermelon (Freq: 4)
#    📈 Aggregating Frequencies: 211 + 173 = 384
#    🗑️  Removed 5 matches from the pool. New pool size: 166
# {'representative_question': {0: 'watermelon foliar application details', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_1': {0: 'Asking about watermelon foliar application information', 1: 'foliar application for water melon', 2: 'water melon foliar spray details', 3: 'Asking about  foliar application details', 4: 'Asked about foliar spray in musk melon ', 5: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan, 5: nan}, 'phase_2': {0: 'Asking about watermelon foliar application information', 1: 'foliar application for water melon', 2: 'water melon foliar spray details', 3: 'Asking about  foliar application details', 4: 'Asked about foliar spray in musk melon ', 5: nan}}
#
# 🔍 Evaluating Reference [0_1]: What is the suitable spacing for watermelon plants? (Current Freq: 182)
#    Candidates remaining in pool: 165
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['392_1', '300_1', '87_1']
#       -> Batch flagged 5 potential IDs: ['620_3', '0_3', '0_2', '77_3', '77_2']
#    [Pass 2] Verifying 8 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [392_1]: What are the best planting methods and spacing for watermelons? (Freq: 20)
#       -> Matched [300_1]: What is the recommended sowing spacing for watermelon? (Freq: 11)
#    📈 Aggregating Frequencies: 182 + 31 = 213
#    🗑️  Removed 2 matches from the pool. New pool size: 163
# {'representative_question': {0: 'Asking about suitable spacing for watermelon', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan}, 'phase_1': {0: 'Asked about water melon planting methods and spacing', 1: 'Sowing spacing for water melon', 2: 'Asking about Watermelon sowing spacing and pit size information ', 3: 'Asking abour seed rate and planting spacing  for watermelon ', 4: 'Asked about Watermelon suitable spacing and yield details ', 5: 'Asked about Watermelon suitable spacing and season', 6: 'Asking about watermelaon season and spacing information', 7: 'Asking about spacing and pit making for watermelon ', 8: nan}, 'false_positive': {0: nan, 1: nan, 2: 'Asking about Watermelon sowing spacing and pit size information ', 3: 'Asking abour seed rate and planting spacing  for watermelon ', 4: 'Asked about Watermelon suitable spacing and yield details ', 5: 'Asked about Watermelon suitable spacing and season', 6: 'Asking about watermelaon season and spacing information', 7: 'Asking about spacing and pit making for watermelon ', 8: nan}, 'phase_2': {0: 'Asked about water melon planting methods and spacing', 1: 'Sowing spacing for water melon', 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan, 8: nan}}
#
# 🔍 Evaluating Reference [195_1]: What is the appropriate use of growth regulators for watermelon? (Current Freq: 118)
#    Candidates remaining in pool: 162
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['133_1', '220_2', '576_4']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [220_2]: What is the correct method for applying growth regulators in watermelon? (Freq: 3)
#    📈 Aggregating Frequencies: 118 + 3 = 121
#    🗑️  Removed 1 matches from the pool. New pool size: 161
# {'representative_question': {0: 'Asking about Growth regulator spray for Watermelon', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'Water melon ethrel application', 1: 'growth regulator application for water melon', 2: 'Asked about if we used ethephon for watermelon', 3: nan}, 'false_positive': {0: 'Water melon ethrel application', 1: nan, 2: 'Asked about if we used ethephon for watermelon', 3: nan}, 'phase_2': {0: 'growth regulator application for water melon', 1: nan, 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [368_1]: What is the recommended seed rate for watermelon? (Current Freq: 94)
#    Candidates remaining in pool: 160
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['376_1']
#       -> Batch flagged 3 potential IDs: ['620_3', '393_6', '542_4']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [376_1]: What is the recommended seed rate for watermelon? (Freq: 31)
#    📈 Aggregating Frequencies: 94 + 31 = 125
#    🗑️  Removed 1 matches from the pool. New pool size: 159
# {'representative_question': {0: 'Asking about seed rate for watermelon', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'seed rate for water melon', 1: 'Asking abour seed rate and planting spacing  for watermelon ', 2: 'Asking about sowing season  seed rate  transplanting age for water melon', 3: ' Asking about number of seedling watermelon per acre', 4: nan}, 'false_positive': {0: nan, 1: 'Asking abour seed rate and planting spacing  for watermelon ', 2: 'Asking about sowing season  seed rate  transplanting age for water melon', 3: ' Asking about number of seedling watermelon per acre', 4: nan}, 'phase_2': {0: 'seed rate for water melon', 1: nan, 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [34_1]: What is the recommended fertigation schedule for watermelon? (Current Freq: 85)
#    Candidates remaining in pool: 158
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asking about seed rate for watermelon', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'seed rate for water melon', 1: 'Asking abour seed rate and planting spacing  for watermelon ', 2: 'Asking about sowing season  seed rate  transplanting age for water melon', 3: ' Asking about number of seedling watermelon per acre', 4: nan}, 'false_positive': {0: nan, 1: 'Asking abour seed rate and planting spacing  for watermelon ', 2: 'Asking about sowing season  seed rate  transplanting age for water melon', 3: ' Asking about number of seedling watermelon per acre', 4: nan}, 'phase_2': {0: 'seed rate for water melon', 1: nan, 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [24_1]: What is the process for treating watermelon seeds before planting? (Current Freq: 75)
#    Candidates remaining in pool: 157
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['557_1']
#       -> Batch flagged 1 potential IDs: ['529_8']
#    [Pass 2] Verifying 2 potential candidates...
#       -> [WARNING] JSON decoding failed in Pass 2.
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asking about seed rate for watermelon', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'seed rate for water melon', 1: 'Asking abour seed rate and planting spacing  for watermelon ', 2: 'Asking about sowing season  seed rate  transplanting age for water melon', 3: ' Asking about number of seedling watermelon per acre', 4: nan}, 'false_positive': {0: nan, 1: 'Asking abour seed rate and planting spacing  for watermelon ', 2: 'Asking about sowing season  seed rate  transplanting age for water melon', 3: ' Asking about number of seedling watermelon per acre', 4: nan}, 'phase_2': {0: 'seed rate for water melon', 1: nan, 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [197_1]: What are the key cultivation practices for watermelon? (Current Freq: 69)
#    Candidates remaining in pool: 156
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['467_5']
#       -> Batch flagged 3 potential IDs: ['314_4', '29_7', '29_4']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [467_5]: What are the cultural practices for growing watermelon? (Freq: 5)
#       -> Matched [314_4]: What are the best practices for growing watermelon? (Freq: 1)
#    📈 Aggregating Frequencies: 69 + 6 = 75
#    🗑️  Removed 2 matches from the pool. New pool size: 154
# {'representative_question': {0: 'watermelon cultivation practices details', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'asked about cultural practices of watermelon', 1: 'YMV in watermelon', 2: 'Thiruvarur Deputy Director of Horticulture', 3: 'Erode horticulture department', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: 'Thiruvarur Deputy Director of Horticulture', 3: 'Erode horticulture department', 4: nan}, 'phase_2': {0: 'asked about cultural practices of watermelon', 1: 'YMV in watermelon', 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [555_1]: What is the total duration required for growing watermelons from planting to harvest? (Current Freq: 60)
#    Candidates remaining in pool: 153
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 5 potential IDs: ['519_1', '555_2', '331_1', '563_2', '555_3']
#       -> Batch flagged 1 potential IDs: ['331_2']
#    [Pass 2] Verifying 6 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [519_1]: At what stage should watermelon be harvested, and what is the typical duration from planting to harvest? (Freq: 17)
#       -> Matched [555_2]: How long does it take for watermelon to grow from planting to harvest? (Freq: 9)
#    📈 Aggregating Frequencies: 60 + 26 = 86
#    🗑️  Removed 2 matches from the pool. New pool size: 151
# {'representative_question': {0: 'Asked about Watermelon total duration', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}, 'phase_1': {0: 'Asking about watermelon harvesting stage and crop duration in days', 1: 'Asked about duration of watermelon', 2: 'Water melon crop duration', 3: 'Asked about watermelon maturity duratiuon for first harvest', 4: 'Asked about watermelon duration and seed availability ', 5: 'water melon duration days', 6: nan}, 'false_positive': {0: nan, 1: nan, 2: 'Water melon crop duration', 3: 'Asked about watermelon maturity duratiuon for first harvest', 4: 'Asked about watermelon duration and seed availability ', 5: 'water melon duration days', 6: nan}, 'phase_2': {0: 'Asking about watermelon harvesting stage and crop duration in days', 1: 'Asked about duration of watermelon', 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}}
#
# 🔍 Evaluating Reference [556_1]: What factors influence the yield of watermelon and how can I maximize it? (Current Freq: 51)
#    Candidates remaining in pool: 150
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['520_1', '466_3', '479_3']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [520_1]: How can I maximize the yield of my watermelon crop? (Freq: 3)
#       -> Matched [466_3]: How can I increase the yield of my watermelons? (Freq: 2)
#       -> Matched [479_3]: How to Increase Yield in Watermelon? (Freq: 1)
#    📈 Aggregating Frequencies: 51 + 6 = 57
#    🗑️  Removed 3 matches from the pool. New pool size: 147
# {'representative_question': {0: 'Asked about yield of watermelon', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'Yield-WATERMELON', 1: 'watermelon yield increase', 2: 'Asking about How to  Increase yield in Water melon', 3: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan}, 'phase_2': {0: 'Yield-WATERMELON', 1: 'watermelon yield increase', 2: 'Asking about How to  Increase yield in Water melon', 3: nan}}
#
# 🔍 Evaluating Reference [499_1]: How can I increase flowering in my watermelon plants? (Current Freq: 46)
#    Candidates remaining in pool: 146
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['516_1', '500_1', '652_1']
#       -> Batch flagged 1 potential IDs: ['485_2']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [516_1]: How can I induce flowering in watermelon plants? (Freq: 13)
#       -> Matched [500_1]: Flower induction in watermelon (Freq: 7)
#       -> Matched [652_1]: How can I increase flowering in watermelon? (Freq: 4)
#    📈 Aggregating Frequencies: 46 + 24 = 70
#    🗑️  Removed 3 matches from the pool. New pool size: 143
# {'representative_question': {0: 'Asked about watermelon increase flowering', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'Asking about Induce flowering in watermelon', 1: 'Flower induces in watermelon', 2: 'Increase flowering in water melon', 3: 'Asking about Watermelon Foliar spray application for Increase Female flowers ', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: 'Asking about Watermelon Foliar spray application for Increase Female flowers ', 4: nan}, 'phase_2': {0: 'Asking about Induce flowering in watermelon', 1: 'Flower induces in watermelon', 2: 'Increase flowering in water melon', 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [424_1]: How can I increase the size of my watermelon fruits? (Current Freq: 42)
#    Candidates remaining in pool: 142
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['451_1', '277_1', '278_4']
#       -> Batch flagged 3 potential IDs: ['20_3', '370_3', '351_3']
#    [Pass 2] Verifying 6 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [451_1]: How can I increase the weight of my watermelons? (Freq: 8)
#       -> Matched [278_4]: How can I increase the size of my watermelon fruits? (Freq: 1)
#    📈 Aggregating Frequencies: 42 + 9 = 51
#    🗑️  Removed 2 matches from the pool. New pool size: 140
# {'representative_question': {0: 'Asked about Watermelon fruit size increase ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}, 'phase_1': {0: 'Asking about Increase Weight in Watermelon', 1: 'Asked about increase fruit quality and size in water melon', 2: 'Increased fruit size', 3: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 4: 'foliar spray for water melon size increase', 5: 'Asking about Water melon foliar spray for Increase Fruit weight ', 6: nan}, 'false_positive': {0: nan, 1: 'Asked about increase fruit quality and size in water melon', 2: nan, 3: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 4: 'foliar spray for water melon size increase', 5: 'Asking about Water melon foliar spray for Increase Fruit weight ', 6: nan}, 'phase_2': {0: 'Asking about Increase Weight in Watermelon', 1: 'Increased fruit size', 2: nan, 3: nan, 4: nan, 5: nan, 6: nan}}
#
# 🔍 Evaluating Reference [133_1]: Water melon ethrel application (Current Freq: 22)
#    Candidates remaining in pool: 139
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['576_4']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [576_4]: Have you used ethephon for watermelon? (Freq: 2)
#    📈 Aggregating Frequencies: 22 + 2 = 24
#    🗑️  Removed 1 matches from the pool. New pool size: 138
# {'representative_question': {0: 'Water melon ethrel application', 1: nan}, 'phase_1': {0: 'Asked about if we used ethephon for watermelon', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about if we used ethephon for watermelon', 1: nan}}
#
# 🔍 Evaluating Reference [528_1]: What is the best method for sowing watermelon seeds? (Current Freq: 21)
#    Candidates remaining in pool: 137
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['100_1', '542_5', '393_3']
#       -> Batch flagged 1 potential IDs: ['529_8']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [100_1]: What is the best way to plant watermelon? (Freq: 16)
#       -> Matched [542_5]: What is the best method for planting watermelon seeds, directly sowing or transplanting? (Freq: 2)
#    📈 Aggregating Frequencies: 21 + 18 = 39
#    🗑️  Removed 2 matches from the pool. New pool size: 135
# {'representative_question': {0: 'Asked about Watermelon sowing method', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'Asking about watermelon planting information', 1: 'Asking about Watermelon seed directly sowing or Transplanting', 2: 'Asking about Water melon sowing and Seedlings  pit information ', 3: 'Asked about preparation of erukku karaisal information', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: 'Asking about Water melon sowing and Seedlings  pit information ', 3: 'Asked about preparation of erukku karaisal information', 4: nan}, 'phase_2': {0: 'Asking about watermelon planting information', 1: 'Asking about Watermelon seed directly sowing or Transplanting', 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [264_1]: What is the suitable soil for watermelon cultivation? (Current Freq: 16)
#    Candidates remaining in pool: 134
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['264_2']
#       -> Batch flagged 1 potential IDs: ['652_3']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [652_3]: What is the ideal soil type for watermelon cultivation? (Freq: 1)
#    📈 Aggregating Frequencies: 16 + 1 = 17
#    🗑️  Removed 1 matches from the pool. New pool size: 133
# {'representative_question': {0: 'Asking about suitable soil for watermelon cultivation', 1: nan, 2: nan}, 'phase_1': {0: 'asking about Suitable soil type and humidity for Watermelon ', 1: 'water melon soil type', 2: nan}, 'false_positive': {0: 'asking about Suitable soil type and humidity for Watermelon ', 1: nan, 2: nan}, 'phase_2': {0: 'water melon soil type', 1: nan, 2: nan}}
#
# 🔍 Evaluating Reference [543_1]: What are the steps for field preparation in watermelon cultivation? (Current Freq: 16)
#    Candidates remaining in pool: 132
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['637_1']
#       -> Batch flagged 3 potential IDs: ['155_6', '543_2', '529_8']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [637_1]: How should I prepare the field for growing watermelons? (Freq: 3)
#       -> Matched [543_2]: What is the proper method for field preparation of watermelon? (Freq: 1)
#    📈 Aggregating Frequencies: 16 + 4 = 20
#    🗑️  Removed 2 matches from the pool. New pool size: 130
# {'representative_question': {0: 'Asking about field preparation in watermelon', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'asking about water melon Preparation of field', 1: 'water  melon field preparation raise beds of 12 m width and 30cm height for sowing', 2: 'Asked about preparation of erukku karaisal information', 3: 'Asking about field preparation of watermelon information', 4: nan}, 'false_positive': {0: nan, 1: 'water  melon field preparation raise beds of 12 m width and 30cm height for sowing', 2: 'Asked about preparation of erukku karaisal information', 3: nan, 4: nan}, 'phase_2': {0: 'asking about water melon Preparation of field', 1: 'Asking about field preparation of watermelon information', 2: nan, 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [498_1]: How can I increase the number of female flowers in my watermelon plants? (Current Freq: 15)
#    Candidates remaining in pool: 129
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 3 potential IDs: ['492_1', '477_1', '500_2']
#       -> Batch flagged 1 potential IDs: ['485_2']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 3 verified matches.
#       -> Matched [492_1]: How to induce the female flower in watermelon? (Freq: 6)
#       -> Matched [477_1]: How can I increase the number of female flowers in watermelon plants? (Freq: 3)
#       -> Matched [500_2]: Female flower induction in watermelon (Freq: 1)
#    📈 Aggregating Frequencies: 15 + 10 = 25
#    🗑️  Removed 3 matches from the pool. New pool size: 126
# {'representative_question': {0: 'Asked about increase female flower in watermelon', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'how to induce the female flower', 1: 'Asking about Increase female flowers in water melon', 2: 'female flower inducing in watermelon', 3: 'Asking about Watermelon Foliar spray application for Increase Female flowers ', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: 'Asking about Watermelon Foliar spray application for Increase Female flowers ', 4: nan}, 'phase_2': {0: 'how to induce the female flower', 1: 'Asking about Increase female flowers in water melon', 2: 'female flower inducing in watermelon', 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [33_2]: What is the recommended fertigation schedule for watermelon during the vegetative stage? (Current Freq: 13)
#    Candidates remaining in pool: 125
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about increase female flower in watermelon', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'how to induce the female flower', 1: 'Asking about Increase female flowers in water melon', 2: 'female flower inducing in watermelon', 3: 'Asking about Watermelon Foliar spray application for Increase Female flowers ', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: 'Asking about Watermelon Foliar spray application for Increase Female flowers ', 4: nan}, 'phase_2': {0: 'how to induce the female flower', 1: 'Asking about Increase female flowers in water melon', 2: 'female flower inducing in watermelon', 3: nan, 4: nan}}
#
# 🔍 Evaluating Reference [423_1]: How can I improve the quality of my watermelon fruits? (Current Freq: 12)
#    Candidates remaining in pool: 124
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['277_1']
#       -> Batch flagged 2 potential IDs: ['370_3', '351_3']
#    [Pass 2] Verifying 3 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [277_1]: How can I increase the quality and size of my watermelon fruits? (Freq: 8)
#    📈 Aggregating Frequencies: 12 + 8 = 20
#    🗑️  Removed 1 matches from the pool. New pool size: 123
# {'representative_question': {0: 'Asked about watermelon increase fruit quality', 1: nan, 2: nan, 3: nan}, 'phase_1': {0: 'Asked about increase fruit quality and size in water melon', 1: 'foliar spray for water melon size increase', 2: 'Asking about Water melon foliar spray for Increase Fruit weight ', 3: nan}, 'false_positive': {0: nan, 1: 'foliar spray for water melon size increase', 2: 'Asking about Water melon foliar spray for Increase Fruit weight ', 3: nan}, 'phase_2': {0: 'Asked about increase fruit quality and size in water melon', 1: nan, 2: nan, 3: nan}}
#
# 🔍 Evaluating Reference [177_1]: Asked about Watermelon top dressing application (Current Freq: 11)
#    Candidates remaining in pool: 122
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['419_2']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [419_2]: Top dressing management for watermelon (Freq: 1)
#    📈 Aggregating Frequencies: 11 + 1 = 12
#    🗑️  Removed 1 matches from the pool. New pool size: 121
# {'representative_question': {0: 'Asked about Watermelon top dressing application ', 1: nan}, 'phase_1': {0: 'top dressing management for watermelon', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'top dressing management for watermelon', 1: nan}}
#
# 🔍 Evaluating Reference [658_1]: What is the best way to intercrop watermelon with other vegetables? (Current Freq: 11)
#    Candidates remaining in pool: 120
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['649_3']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Watermelon top dressing application ', 1: nan}, 'phase_1': {0: 'top dressing management for watermelon', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'top dressing management for watermelon', 1: nan}}
#
# 🔍 Evaluating Reference [563_1]: What is the best time to harvest watermelons? (Current Freq: 11)
#    Candidates remaining in pool: 119
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 6 potential IDs: ['521_3', '563_2', '479_2', '653_2', '442_6', '564_2']
#       -> Batch flagged 1 potential IDs: ['521_7']
#    [Pass 2] Verifying 7 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [521_3]: When is the first harvest time for watermelon? (Freq: 8)
#       -> Matched [521_7]: What is the best time to pick watermelons? (Freq: 1)
#    📈 Aggregating Frequencies: 11 + 9 = 20
#    🗑️  Removed 2 matches from the pool. New pool size: 117
# {'representative_question': {0: 'Asked about harvest information for watermelon ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}, 'phase_1': {0: 'Asking about first harvest time for watermelon', 1: 'Asked about watermelon maturity duratiuon for first harvest', 2: 'Asking about Water melon Harvesting stage information', 3: 'harvesting period of water melon', 4: 'Asked about water melon durationyield and harvest information ', 5: 'Asked about Watermelon first picking and Harvesting details ', 6: 'Asking about watermelon first picking information ', 7: nan}, 'false_positive': {0: nan, 1: 'Asked about watermelon maturity duratiuon for first harvest', 2: 'Asking about Water melon Harvesting stage information', 3: 'harvesting period of water melon', 4: 'Asked about water melon durationyield and harvest information ', 5: 'Asked about Watermelon first picking and Harvesting details ', 6: nan, 7: nan}, 'phase_2': {0: 'Asking about first harvest time for watermelon', 1: 'Asking about watermelon first picking information ', 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}}
#
# 🔍 Evaluating Reference [531_1]: What is the Watermelon Harvesting Index and how is it determined? (Current Freq: 10)
#    Candidates remaining in pool: 116
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about harvest information for watermelon ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}, 'phase_1': {0: 'Asking about first harvest time for watermelon', 1: 'Asked about watermelon maturity duratiuon for first harvest', 2: 'Asking about Water melon Harvesting stage information', 3: 'harvesting period of water melon', 4: 'Asked about water melon durationyield and harvest information ', 5: 'Asked about Watermelon first picking and Harvesting details ', 6: 'Asking about watermelon first picking information ', 7: nan}, 'false_positive': {0: nan, 1: 'Asked about watermelon maturity duratiuon for first harvest', 2: 'Asking about Water melon Harvesting stage information', 3: 'harvesting period of water melon', 4: 'Asked about water melon durationyield and harvest information ', 5: 'Asked about Watermelon first picking and Harvesting details ', 6: nan, 7: nan}, 'phase_2': {0: 'Asking about first harvest time for watermelon', 1: 'Asking about watermelon first picking information ', 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}}
#
# 🔍 Evaluating Reference [448_1]: What is basal application for watermelon and how should it be done? (Current Freq: 9)
#    Candidates remaining in pool: 115
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['229_2', '491_3']
#    [Pass 2] Verifying 2 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about harvest information for watermelon ', 1: nan, 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}, 'phase_1': {0: 'Asking about first harvest time for watermelon', 1: 'Asked about watermelon maturity duratiuon for first harvest', 2: 'Asking about Water melon Harvesting stage information', 3: 'harvesting period of water melon', 4: 'Asked about water melon durationyield and harvest information ', 5: 'Asked about Watermelon first picking and Harvesting details ', 6: 'Asking about watermelon first picking information ', 7: nan}, 'false_positive': {0: nan, 1: 'Asked about watermelon maturity duratiuon for first harvest', 2: 'Asking about Water melon Harvesting stage information', 3: 'harvesting period of water melon', 4: 'Asked about water melon durationyield and harvest information ', 5: 'Asked about Watermelon first picking and Harvesting details ', 6: nan, 7: nan}, 'phase_2': {0: 'Asking about first harvest time for watermelon', 1: 'Asking about watermelon first picking information ', 2: nan, 3: nan, 4: nan, 5: nan, 6: nan, 7: nan}}
#
# 🔍 Evaluating Reference [566_1]: What is the typical germination period for watermelon seeds? (Current Freq: 9)
#    Candidates remaining in pool: 114
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['530_1']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [530_1]: In how many days will watermelon seeds germinate after sowing? (Freq: 6)
#    📈 Aggregating Frequencies: 9 + 6 = 15
#    🗑️  Removed 1 matches from the pool. New pool size: 113
# {'representative_question': {0: 'Asked about Watermelon germination period ', 1: nan}, 'phase_1': {0: 'Asking about  in how many days watermelon seed will germination after sowing ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asking about  in how many days watermelon seed will germination after sowing ', 1: nan}}
#
# 🔍 Evaluating Reference [422_1]: What is the best practice for drip fertigation management in watermelon? (Current Freq: 9)
#    Candidates remaining in pool: 112
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['11_1']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Watermelon germination period ', 1: nan}, 'phase_1': {0: 'Asking about  in how many days watermelon seed will germination after sowing ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asking about  in how many days watermelon seed will germination after sowing ', 1: nan}}
#
# 🔍 Evaluating Reference [155_4]: Watermelon sowing season details (Current Freq: 7)
#    Candidates remaining in pool: 111
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 5 potential IDs: ['393_4', '393_6', '0_2', '77_3', '315_2']
#    [Pass 2] Verifying 5 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Watermelon germination period ', 1: nan}, 'phase_1': {0: 'Asking about  in how many days watermelon seed will germination after sowing ', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asking about  in how many days watermelon seed will germination after sowing ', 1: nan}}
#
# 🔍 Evaluating Reference [352_1]: What are the best practices for managing flower and fruit setting in watermelon? (Current Freq: 7)
#    Candidates remaining in pool: 110
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 2 potential IDs: ['614_1', '465_1']
#    [Pass 2] Verifying 2 potential candidates...
#    ✅ SUCCESS: Found 2 verified matches.
#       -> Matched [614_1]: How to increase fruit setting for watermelon? (Freq: 4)
#       -> Matched [465_1]: How can I enhance watermelon flowers to improve fruit set and yield? (Freq: 2)
#    📈 Aggregating Frequencies: 7 + 6 = 13
#    🗑️  Removed 2 matches from the pool. New pool size: 108
# {'representative_question': {0: 'Asking about Flower and Fruit setting management for Watermelon ', 1: nan, 2: nan}, 'phase_1': {0: 'How to increase fruit setting for water melon', 1: 'Asking about watermelon flowers enhancing', 2: nan}, 'false_positive': {0: nan, 1: nan, 2: nan}, 'phase_2': {0: 'How to increase fruit setting for water melon', 1: 'Asking about watermelon flowers enhancing', 2: nan}}
#
# 🔍 Evaluating Reference [565_1]: What is the ideal age for transplanting watermelon seedlings? (Current Freq: 7)
#    Candidates remaining in pool: 107
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['393_6']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asking about Flower and Fruit setting management for Watermelon ', 1: nan, 2: nan}, 'phase_1': {0: 'How to increase fruit setting for water melon', 1: 'Asking about watermelon flowers enhancing', 2: nan}, 'false_positive': {0: nan, 1: nan, 2: nan}, 'phase_2': {0: 'How to increase fruit setting for water melon', 1: 'Asking about watermelon flowers enhancing', 2: nan}}
#
# 🔍 Evaluating Reference [52_1]: Asked about Foliar spray for Watermelon growth increase (Current Freq: 6)
#    Candidates remaining in pool: 106
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 4 potential IDs: ['74_1', '20_3', '370_3', '351_3']
#    [Pass 2] Verifying 4 potential candidates...
#    ✅ SUCCESS: Found 4 verified matches.
#       -> Matched [74_1]: How can foliar sprays be used to increase yield in watermelons? (Freq: 5)
#       -> Matched [20_3]: Asked about foliar spray application for fruit size enlargement in watermelon (Freq: 1)
#       -> Matched [370_3]: Foliar spray for watermelon size increase (Freq: 1)
#       -> Matched [351_3]: What is the best foliar spray for increasing the weight of watermelon fruits? (Freq: 1)
#    📈 Aggregating Frequencies: 6 + 8 = 14
#    🗑️  Removed 4 matches from the pool. New pool size: 102
# {'representative_question': {0: 'Asked about Foliar spray for Watermelon growth increase', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'Asking about foliar spray in watermelonto increase yield ', 1: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 2: 'foliar spray for water melon size increase', 3: 'Asking about Water melon foliar spray for Increase Fruit weight ', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_2': {0: 'Asking about foliar spray in watermelonto increase yield ', 1: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 2: 'foliar spray for water melon size increase', 3: 'Asking about Water melon foliar spray for Increase Fruit weight ', 4: nan}}
#
# 🔍 Evaluating Reference [264_2]: What is the suitable soil type and humidity for growing watermelons? (Current Freq: 6)
#    Candidates remaining in pool: 101
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['355_6']
#    [Pass 2] Verifying 1 potential candidates...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Foliar spray for Watermelon growth increase', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'Asking about foliar spray in watermelonto increase yield ', 1: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 2: 'foliar spray for water melon size increase', 3: 'Asking about Water melon foliar spray for Increase Fruit weight ', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_2': {0: 'Asking about foliar spray in watermelonto increase yield ', 1: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 2: 'foliar spray for water melon size increase', 3: 'Asking about Water melon foliar spray for Increase Fruit weight ', 4: nan}}
#
# 🔍 Evaluating Reference [626_2]: What are the suitable vegetable crops to plant in April? (Current Freq: 6)
#    Candidates remaining in pool: 100
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Foliar spray for Watermelon growth increase', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'Asking about foliar spray in watermelonto increase yield ', 1: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 2: 'foliar spray for water melon size increase', 3: 'Asking about Water melon foliar spray for Increase Fruit weight ', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_2': {0: 'Asking about foliar spray in watermelonto increase yield ', 1: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 2: 'foliar spray for water melon size increase', 3: 'Asking about Water melon foliar spray for Increase Fruit weight ', 4: nan}}
#
# 🔍 Evaluating Reference [11_1]: What is the recommended fertigation schedule for watermelon from flower initiation to the first picking? (Current Freq: 6)
#    Candidates remaining in pool: 99
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about Foliar spray for Watermelon growth increase', 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_1': {0: 'Asking about foliar spray in watermelonto increase yield ', 1: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 2: 'foliar spray for water melon size increase', 3: 'Asking about Water melon foliar spray for Increase Fruit weight ', 4: nan}, 'false_positive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}, 'phase_2': {0: 'Asking about foliar spray in watermelonto increase yield ', 1: 'Asked about foliar spray application  for fruit size enlargement  in watermelon\t', 2: 'foliar spray for water melon size increase', 3: 'Asking about Water melon foliar spray for Increase Fruit weight ', 4: nan}}
#
# 🔍 Evaluating Reference [645_1]: What are the management practices for stunted growth in watermelon plants? (Current Freq: 6)
#    Candidates remaining in pool: 98
#    [Pass 1] Scanning for initial candidates...
# ...
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about grass hopper management in watermelon crop ', 1: nan}, 'phase_1': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}}
#
# 🔍 Evaluating Reference [382_2]: What is the sowing season for small onions? (Current Freq: 4)
#    Candidates remaining in pool: 9
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about grass hopper management in watermelon crop ', 1: nan}, 'phase_1': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}}
#
# 🔍 Evaluating Reference [382_1]: What is the sowing season for Blackgram in Cuddalore? (Current Freq: 4)
#    Candidates remaining in pool: 8
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about grass hopper management in watermelon crop ', 1: nan}, 'phase_1': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}}
#
# 🔍 Evaluating Reference [68_1]: Asked about Ash Gourd Sowing season and Variety (Current Freq: 4)
#    Candidates remaining in pool: 7
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about grass hopper management in watermelon crop ', 1: nan}, 'phase_1': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}}
#
# 🔍 Evaluating Reference [263_1]: Asking about snake gourd foliar application (Current Freq: 3)
#    Candidates remaining in pool: 6
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about grass hopper management in watermelon crop ', 1: nan}, 'phase_1': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}}
#
# 🔍 Evaluating Reference [50_2]: Asking about Amaranthus seeds availability (Current Freq: 1)
#    Candidates remaining in pool: 5
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about grass hopper management in watermelon crop ', 1: nan}, 'phase_1': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}}
#
# 🔍 Evaluating Reference [263_2]: Asking about Ash gourd foliar application information (Current Freq: 1)
#    Candidates remaining in pool: 4
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'Asked about grass hopper management in watermelon crop ', 1: nan}, 'phase_1': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about how to control the grasshopper attack on the watermelon plant', 1: nan}}
#
# 🔍 Evaluating Reference [529_10]: Asked about the groundnut oilcake preparation method (Current Freq: 1)
#    Candidates remaining in pool: 3
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#       -> Batch flagged 1 potential IDs: ['529_7']
#    [Pass 2] Verifying 1 potential candidates...
#    ✅ SUCCESS: Found 1 verified matches.
#       -> Matched [529_7]: Asked about groundnut cake preparation (Freq: 1)
#    📈 Aggregating Frequencies: 1 + 1 = 2
#    🗑️  Removed 1 matches from the pool. New pool size: 2
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [529_6]: Asked about groundnut cake application method information (Current Freq: 1)
#    Candidates remaining in pool: 1
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# [INFO] Only 1 row left in category. Saving Reference [529_5] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Pest and Disease
# ======================================================================
# [INFO] Total rows to process in 'Pest and Disease': 2
#
# 🔍 Evaluating Reference [618_1]: How can I diagnose and manage pests and diseases in my watermelon plants? (Current Freq: 7)
#    Candidates remaining in pool: 1
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# [INFO] Only 1 row left in category. Saving Reference [160_2] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Other
# ======================================================================
# [INFO] Total rows to process in 'Other': 11
#
# 🔍 Evaluating Reference [581_7]: Asked about panchakavyam foliar application in watermelon (Current Freq: 4)
#    Candidates remaining in pool: 10
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [29_3]: Thirunelveli horticulture department number (Current Freq: 2)
#    Candidates remaining in pool: 9
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [350_6]: Asking about Pesticide Price information (Current Freq: 2)
#    Candidates remaining in pool: 8
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [257_3]: What vegetables are suitable for planting in January? (Current Freq: 2)
#    Candidates remaining in pool: 7
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [216_2]: Asking about Watermelon seed availability contact (Current Freq: 1)
#    Candidates remaining in pool: 6
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [627_7]: What are the suitable watermelon varieties for planting in this season? (Current Freq: 1)
#    Candidates remaining in pool: 5
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [627_6]: What are some suitable horticulture crops for a small farm? (Current Freq: 1)
#    Candidates remaining in pool: 4
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [189_3]: What is the appropriate foliar nutrient spray for snake gourd? (Current Freq: 1)
#    Candidates remaining in pool: 3
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [29_6]: Thiruvannamalai horticulture department number (Current Freq: 1)
#    Candidates remaining in pool: 2
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# 🔍 Evaluating Reference [529_3]: How can I prepare a buttermilk solution for watermelon? (Current Freq: 1)
#    Candidates remaining in pool: 1
#    [Pass 1] Scanning for initial candidates...
# Pass 1 Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#    ❌ No matches found. Moving to next row.
# {'representative_question': {0: 'asked about groundnut oilcake preparation method\t\n', 1: nan}, 'phase_1': {0: 'Asked about groundnut cake preparation', 1: nan}, 'false_positive': {0: nan, 1: nan}, 'phase_2': {0: 'Asked about groundnut cake preparation', 1: nan}}
#
# [INFO] Only 1 row left in category. Saving Reference [29_9] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Fungicide and Nutrient
# ======================================================================
# [INFO] Total rows to process in 'Fungicide and Nutrient': 1
#
# [INFO] Only 1 row left in category. Saving Reference [216_4] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Weed Management
# ======================================================================
# [INFO] Total rows to process in 'Weed Management': 1
#
# [INFO] Only 1 row left in category. Saving Reference [146_2] directly.
#
# ======================================================================
# 🚀 STARTING CATEGORY: Disease and Pest
# ======================================================================
# [INFO] Total rows to process in 'Disease and Pest': 1
#
# [INFO] Only 1 row left in category. Saving Reference [228_6] directly.
#
# ======================================================================
# 🎉 PROCESSING COMPLETE
# ======================================================================
# Original Dataset Size: 622
# Cleaned Dataset Size: 311
# Saved phase output: phase_data_watermelon_faq.csv
# Saved final output: dedup_watermelon_faq.csv
# Processing: phase_data_watermelon_faq.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'raw_frequency'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 21
#      18 df = pd.read_csv(csv_file, low_memory=False)
#      20 # Apply your function
# ---> 21 df, df1 = deduplicate_and_aggregate(df)
#      23 df1.to_csv(output_path_phase, index=False)
#      25 # Filter
#
# Cell In[28], line 12, in deduplicate_and_aggregate(df, text_col, batch_size)
#       7 """
#       8 Iterates through categories, finds similar questions using LLM,
#       9 aggregates 'raw_frequency', and removes duplicates with full logging.
#      10 """
#      11 # Ensure raw_frequency is numeric to allow summing
# ---> 12 df['raw_frequency'] = pd.to_numeric(df['raw_frequency'], errors='coerce').fillna(0)
#      14 phase_data = []
#      15 final_cleaned_data = []
#
# File /srv/venv/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /srv/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'raw_frequency'

# %%
ref_phase1 = pd.DataFrame({
        'representative_question': ['HOW TO CONTROL THREAD WORMS IN PADDY FIELD', np.nan, np.nan, np.nan, np.nan, np.nan],                                                           
        'phase_1': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Threadworm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 'Threadworms in paddy', 'infomation regarding threadworm in paddy', 'thread worm in paddy'],                                                                                   
        'phase_1_id': ['39_1', '65_1', '66_1', '486_1', '482_11', '65_2'],
        'phase_2': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Threadworm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD','Threadworms in paddy', 'infomation regarding threadworm in paddy', np.nan],               
        'phase_2_id': ['39_1', '65_1', '66_1', '486_1', '482_11', np.nan],                   
    })                                                                                       
   
ref_phase2 = pd.DataFrame({                                                                
        'representative_question': ['BEST FERTILIZER FOR WHEAT CROP', np.nan, np.nan,np.nan],
        'phase_1': ['fertilizer for wheat', 'which fertilizer for wheat', 'nutrient management in wheat', 'manure for wheat crop'],                                            
        'phase_1_id': ['10_1', '11_1', '12_1', '13_1'],
        'phase_2': ['fertilizer for wheat', 'which fertilizer for wheat', 'nutrient management in wheat', np.nan],                                                             
        'phase_2_id': ['10_1', '11_1', '12_1', np.nan],
    })                                                                                       
                                                            
phase_data = []                                                                            
   
for ref_phase in [ref_phase1, ref_phase2]:                                                 
      phase_2_ids = set(ref_phase['phase_2_id'].dropna())   
      removed_mask = ~ref_phase['phase_1_id'].isin(phase_2_ids)
      ref_phase['false_positive'] = ref_phase.loc[removed_mask, 'phase_1']                   
      false_positives = ref_phase['false_positive'].dropna()
      ref_phase['false_positive'] = false_positives                                          
      ref_phase.drop(columns=['phase_1_id', 'phase_2_id'], inplace=True)                     
      ref_phase = ref_phase[['representative_question', 'phase_1', 'false_positive','phase_2']]                                                                                
      ref_phase = pd.concat([ref_phase, pd.DataFrame([{}])], ignore_index=True)
      phase_data.append(ref_phase)                                                           
                                                            
pd.concat(phase_data, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 ref_phase1 = pd.DataFrame({
# ----> 2         'representative_question': ['HOW TO CONTROL THREAD WORMS IN PADDY FIELD', np.nan, np.nan, np.nan, np.nan, np.nan],
#       3         'phase_1': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Threadworm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD', 'Threadworms in paddy', 'infomation regarding threadworm in paddy', 'thread worm in paddy'],
#       4         'phase_1_id': ['39_1', '65_1', '66_1', '486_1', '482_11', '65_2'],
#       5         'phase_2': ['CONTROL OF THREADWORMS IN PADDY', 'Farmer asked a query regarding Threadworm problem in paddy', 'REGARDING THE ATTACK OF THREAD WORMS IN PADDY FIELD','Threadworms in paddy', 'infomation regarding threadworm in paddy', np.nan],
#       6         'phase_2_id': ['39_1', '65_1', '66_1', '486_1', '482_11', np.nan],
#       7     })
#       9 ref_phase2 = pd.DataFrame({
#      10         'representative_question': ['BEST FERTILIZER FOR WHEAT CROP', np.nan, np.nan,np.nan],
#      11         'phase_1': ['fertilizer for wheat', 'which fertilizer for wheat', 'nutrient management in wheat', 'manure for wheat crop'],
#    (...)     14         'phase_2_id': ['10_1', '11_1', '12_1', np.nan],
#      15     })
#      17 phase_data = []
#
# NameError: name 'np' is not defined
